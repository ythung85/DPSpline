# %%
import matplotlib.pyplot as plt
from torch import nn
import seaborn as sns
import pandas as pd
import numpy as np
import torch
import math
import random
import warnings
import torchvision
from collections.abc import Callable
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## Synthesis Data

# %%
def sim_data(n, dim, Type):
    
    #noise = torch.normal(0, noiseL, size=(n, 1))

    if Type == 'A':
        X = torch.rand((n, dim))
        y = 1
        for d in range(dim):
            a = (d+1)/2
            y *= ((torch.abs(4*X[:,d]-2)+a)/(1+a))
        y = y.reshape(-1,1)
        y = y.float()

    elif Type == 'B':
        X = torch.rand((n, dim))
        y = torch.zeros((n))
        for i in range(dim):
            y += ((-1**(i+1)/(i+1))*X[:,i])
        y = y.reshape(-1,1)
        y = -y.float()
        
    elif Type == 'C':
        # noise level should be 0.01
        X = torch.rand((n, 4))
        y = torch.exp(X[:,0]**2-torch.sqrt(X[:,1]+5))+0.01*torch.arctan(1/(0.01+torch.abs(X[:,2]+X[:,3])))
        y = y.reshape(-1,1)
        y = y.float()

    elif Type == 'D':
        X = torch.rand((n, dim))
        
    else:
        pass
    
    #return X, y + noise
    return X, y

def norm(x):
    return (x-torch.min(x))/(torch.max(x)-torch.min(x))

def diag_mat_weights(dimp, type = 'first'):
    if type == 'first':
        dg = np.zeros((dimp-1, dimp))
        for i in range(dimp-1):
            dg[i,i] = -1
            dg[i,i+1]= 1
    elif type == 'second':
        dg = np.zeros((dimp-2, dimp))
        for i in range(dimp-2):
            dg[i,i] = -1
            dg[i,i+1]= 2
            dg[i,i+2]= -1
    else:
        pass
    return torch.Tensor(dg)

# %%
trainsize = 800; testsize = 400
error_ratio = 0.05
ndim = 2


# Training 
torch.manual_seed(0)

X_train, y_train = sim_data(trainsize, ndim, 'C')
eps_train = torch.normal(0, torch.var(y_train)*error_ratio, size=(trainsize, 1))
y_train += eps_train

# Testing 
torch.manual_seed(1)
X_test, y_test = sim_data(testsize, ndim, 'C')
eps_test = torch.normal(0, torch.var(y_test)*error_ratio, size=(testsize, 1))
y_test += eps_test
#np.savez_compressed('./dataset/stdex3n800.npz', Xtrain=X_train, ytrain=y_train, Xtest=X_test, ytest=y_test)

print(X_train.size(), y_train.size(), X_test.size(), y_test.size())
# Out:
# torch.Size([800, 4]) torch.Size([800, 1]) torch.Size([400, 4]) torch.Size([400, 1])

# %% [markdown]
# ## Chip data

# %%
def normalize_columns(tensor, type = None):
    # Calculate the maximum value for each column
    if type == 'standard':
        mean, std = tensor.mean(dim = 0), tensor.std(dim = 0)
    
        # Normalize each column by dividing by its maximum value
        for i in range(tensor.size()[1]):
            tensor[:,i] = (tensor[:,i]- mean[i])/std[i]
    else:
        Max, Min = tensor.max(dim = 0)[0], tensor.min(dim = 0)[0]
    
        # Normalize each column by dividing by its maximum value
        for i in range(tensor.size()[1]):
            tensor[:,i] = (tensor[:,i]- Min[i])/(Max[i] - Min[i])
    
    return tensor

def ECM(model, num_neurons, num_knots, initial_xi = 1, initial_sigma = 1, initial_lambda = 1e-4, L = None):
    lambdab = initial_lambda
    sigma = initial_sigma
    xi = initial_xi

    if L == 1:
        B = model.inter['ebasic']
        By = model.inter['basic']
        WB = model.sp1.control_p
    else:
        B = model.inter['ebasic2']
        By = model.inter['basic2']
        WB = model.sp2.control_p
        
    DB = diag_mat_weights(WB.size()[0]).to(device)
    size = B.size()[1]
    S = DB.T @ DB
    Cov_a = (xi**2)* torch.linalg.pinv(S)
    Cov_e = torch.eye(size*num_neurons)* sigma
    
    block_y = torch.reshape(By, (-1,1))
    flatB = B.view(num_neurons, num_knots, size)
        
    sqr_xi= 0
    sqr_sig = 0
    
    for i in range(num_neurons):
        Ncov = (Cov_a -(Cov_a @ flatB[i]) @ (torch.linalg.pinv(flatB[i].T @ Cov_a @ flatB[i] + Cov_e[size*i:size*(i+1),size*i:size*(i+1)]) @ flatB[i].T @ Cov_a))
        Nmu = (Cov_a @ flatB[i]) @ (torch.linalg.pinv(flatB[i].T @ Cov_a @ flatB[i] + Cov_e[size*i:size*(i+1),size*i:size*(i+1)])) @ By[:,i].reshape(-1,1)
        
        first_xi = S @ Ncov
        second_xi = (Nmu.T @ S @ Nmu)
        sqr_xi += torch.trace(first_xi) + second_xi
            
        first_sig = torch.norm(By[:,i])
        second_sig = 2 * (By[:,i] @ flatB[i].T) @ Nmu 
        third_sig = torch.trace((flatB[i] @ flatB[i].T) @ Ncov)
        four_sig = (Nmu.T @ flatB[i] @ flatB[i].T @ Nmu)
        
        sqr_sig += (first_sig + second_sig + third_sig + four_sig)
    
    sqr_xi /= num_neurons
    sqr_sig /= (num_neurons*size)
    
    Lambda = sqr_sig/sqr_xi
    
    return Lambda.item()

# %%
trainsample = np.array(pd.read_csv('/Users/a080528/Desktop/Github/DBspline/trainsample.csv'))
testsample = np.array(pd.read_csv('/Users/a080528/Desktop/Github/DBspline/testsample.csv'))

# %%
# Three size of chip
WLsize = [6.4*10**(-4), 6.4*10**(-6), 6.4*10**(-8)]

# Fix A, a, b, c, d, V
A = 5*10**(-7); a = -78; b = 0.081; c = 8.81*10**(3); d = -7.75 * 10**(5); V = 1.2

# Change size, beta, and Temperature
beta = 1.64; T = 120; WL = 6.4*10**(-4)

# upper and lower bound
lA = 4.75*10**(-7); uA = 5.25*10**(-7)
la = -74.1; ua = -81.9
lb = 7.695 * 10**(-2); ub = 8.505 * 10**(-2)
lc =  8.369*10**(3); uc =  9.250*10**(3)
ld = -7.3265 * 10**(5); ud = -8.1375 * 10**(5)

lbeta = 1.476; ubeta = 1.804
lT = 120; uT = 180
lV = 1.2; uV = 1.3
lWL = 6*10**(-4); uWL = 4*10**(-4)

# sampling 
sample_train_A = lA + trainsample[:,0]*(uA - lA)
sample_train_a = la + trainsample[:,1]*(ua - la)
sample_train_b = lb + trainsample[:,2]*(ub - lb)
sample_train_c = lc + trainsample[:,3]*(uc - lc)
sample_train_d = ld + trainsample[:,4]*(ud - ld)
sample_train_beta = lbeta + trainsample[:,5]*(ubeta - lbeta)
sample_train_T = lT + trainsample[:,6]*(uT - lT)
sample_train_V = lV + trainsample[:,7]*(uV - lV)
sample_train_WL = lWL + trainsample[:,8]*(uWL - lWL)
sample_train_eta = sample_train_A*(sample_train_WL*np.exp(1))**(-1/sample_train_beta)*(sample_train_V**(sample_train_a+sample_train_b*sample_train_T))*np.exp((sample_train_c*sample_train_T+sample_train_d)/sample_train_T**2)


sample_test_beta = lbeta + testsample[:,0]*(ubeta - lbeta)
sample_test_T = lT + testsample[:,1]*(uT - lT)
sample_test_WL = lWL + testsample[:,2]*(uWL - lWL)
sample_test_eta = A*(sample_test_WL*np.exp(1))**(-1/sample_test_beta)*(V**(a+b*sample_test_T))*np.exp((c*sample_test_T+d)/sample_test_T**2)

sample_test_A = lA + testsample[:,0]*(uA - lA)
sample_test_a = la + testsample[:,1]*(ua - la)
sample_test_b = lb + testsample[:,2]*(ub - lb)
sample_test_c = lc + testsample[:,3]*(uc - lc)
sample_test_d = ld + testsample[:,4]*(ud - ld)
sample_test_beta = lbeta + testsample[:,5]*(ubeta - lbeta)
sample_test_T = lT + testsample[:,6]*(uT - lT)
sample_test_V = lV + testsample[:,7]*(uV - lV)
sample_test_WL = lWL + testsample[:,8]*(uWL - lWL)
sample_test_eta = sample_test_A*(sample_test_WL*np.exp(1))**(-1/sample_test_beta)*(sample_test_V**(sample_test_a+sample_test_b*sample_test_T))*np.exp((sample_test_c*sample_test_T+sample_test_d)/sample_test_T**2)


def psurvival(t, eta, beta):
    return 1-np.exp(-(t/eta)**beta)

# %%
ndim = 9

X_train = torch.zeros((sample_train_beta.shape[0], ndim))
X_test = torch.zeros((sample_test_beta.shape[0], ndim))

X_train[:,0] = torch.Tensor(sample_train_A)
X_train[:,1] = torch.Tensor(sample_train_a)
X_train[:,2] = torch.Tensor(sample_train_b)
X_train[:,3] = torch.Tensor(sample_train_c)
X_train[:,4] = torch.Tensor(sample_train_d)
X_train[:,5] = torch.Tensor(sample_train_beta)
X_train[:,6] = torch.Tensor(sample_train_T)
X_train[:,7] = torch.Tensor(sample_train_V)
X_train[:,8] = torch.Tensor(sample_train_WL)


X_test[:,0] = torch.Tensor(sample_test_A)
X_test[:,1] = torch.Tensor(sample_test_a)
X_test[:,2] = torch.Tensor(sample_test_b)
X_test[:,3] = torch.Tensor(sample_test_c)
X_test[:,4] = torch.Tensor(sample_test_d)
X_test[:,5] = torch.Tensor(sample_test_beta)
X_test[:,6] = torch.Tensor(sample_test_T)
X_test[:,7] = torch.Tensor(sample_test_V)
X_test[:,8] = torch.Tensor(sample_test_WL)

y_train = torch.Tensor(sample_train_eta).reshape(-1, 1)
y_test = torch.Tensor(sample_test_eta).reshape(-1, 1)

X_train, X_test = normalize_columns(X_train, type = 'standard'), normalize_columns(X_test, type = 'standard')

# %%
trainsize, testsize = 1000, 400


aprange = [(y_train >= 1) & (y_train<= 30)]
DataX, Datay = X_train[aprange[0][:,0]], y_train[aprange[0][:,0]]

indice = random.sample(range(DataX.size()[0]), trainsize + testsize)
train_indice, test_indice = torch.tensor(indice[:trainsize]), torch.tensor(indice[trainsize:])

X_train, X_test, y_train, y_test = DataX[train_indice,:], DataX[test_indice,:], Datay[train_indice], Datay[test_indice]
y_train, y_test = torch.log(y_train), torch.log(y_test)

# %%
plt.figure(figsize=(12,4))
plt.subplot(1,2,1)
plt.scatter(np.arange(y_train.shape[0]), y_train)
plt.title('Training $\eta$')
plt.subplot(1,2,2)
plt.scatter(np.arange(y_test.shape[0]), y_test)
plt.title('Testing $\eta$')
plt.show()

# %% [markdown]
# # Modeling 1-Spline

# %%
class PRODBSplineLayerMultiFeature(nn.Module):
    def __init__(self, input_dim, degree, num_knots, output_dim, num_neurons, bias = True):
        super(PRODBSplineLayerMultiFeature, self).__init__()
        self.degree = degree
        self.num_knots = num_knots
        self.input_dim = input_dim
        self.output_dim = output_dim
        self.num_neurons = num_neurons
        
        if input_dim == 2:
            self.control_p = nn.Parameter(torch.randn(self.num_knots**2, self.output_dim))
        else:
            self.control_p = nn.Parameter(torch.randn(self.num_knots, self.num_neurons))
        if bias:
            self.bias = nn.Parameter(torch.randn(self.num_neurons))
        else:
            self.register_parameter('bias', None)
            
        self.inter = {}
    
    def basis_function(self, x, i, k, t):
    
        # Base case: degree 0 spline
        if k == 0:
            return ((t[i] <= x) & (x < t[i + 1])).float()
    
        # Recursive case
        denom1 = t[i + k] - t[i]
        denom2 = t[i + k + 1] - t[i + 1]
    
        term1 = 0
        if denom1 != 0:
            term1 = (x - t[i]) / denom1 * self.basis_function(x, i, k - 1, t)
    
        term2 = 0
        if denom2 != 0:
            term2 = (t[i + k + 1] - x) / denom2 * self.basis_function(x, i + 1, k - 1, t)
    
        return term1 + term2
    
    def forward(self, x):
        batch_size, num_features = x.size()
        device = x.device
        
        # Create knot vector
        # knots = torch.linspace(0, 1, self.num_knots + self.degree + 1).to(device)
        knots = torch.cat([
                        torch.zeros(self.degree),               # Add repeated values at the start for clamping
                        torch.linspace(0, 1, self.num_knots - self.degree + 1),  # Uniform knot spacing in the middle
                        torch.ones(self.degree)                 # Add repeated values at the end for clamping
                    ]).to(device)
        # Apply B-spline basis functions for each feature
        basises = []
    
        
        for feature in range(num_features):
            # Calculate B-spline basis functions for this feature
            basis = torch.stack([self.basis_function(x[:, feature], i, self.degree, knots) 
                                 for i in range(self.num_knots)], dim=-1)
            basises.append(basis)
            
        
        if num_features == 1:
            tout = basises[0] @ self.control_p
            self.inter['basic'] = basises[0].T
        else:
            self.inter['basic'] = torch.reshape(torch.stack(basises, dim = 1), (batch_size, self.num_knots * self.num_neurons)).T
            basises = torch.stack(basises)
            tout = basises.permute(1,2,0) * self.control_p
            tout = tout.sum(dim =1)
                
        if self.bias is not None:
            tout += self.bias        
            
        return tout


class NormLayer(nn.Module):
    def __init__(self):
        super(NormLayer, self).__init__()

    def forward(self, x):
        min_val = torch.min(x, axis = 1).values.reshape(-1,1)
        max_val = torch.max(x, axis = 1).values.reshape(-1,1)

        x = (x - min_val)/(max_val - min_val)  # Rescale to [0, 1]
        return x.detach()

# %%
class MPSv3(nn.Module):
    def __init__(self, input_dim, degree, num_knots, num_neurons, output_dim, nkernel, bias):
        super(MPSv3, self).__init__()
        self.num_neurons = num_neurons
        self.num_knots = num_knots
        #self.nkernel = nkernel
        self.ln1 = nn.Linear(input_dim, num_neurons)
        self.nm1 = NormLayer() 
        self.sp1 = PRODBSplineLayerMultiFeature(input_dim = 1, degree = degree, num_knots = num_knots, num_neurons = num_neurons, output_dim= output_dim, bias = True)
        self.ln2 = nn.Linear(num_neurons, output_dim)
        self.drop1 = nn.Dropout(p=0.1)
        #self.drop2 = nn.Dropout(p=0.1)
        #>>> m = nn.Dropout(p=0.2)
        '''
        self.rbf = RBFLayer(in_features_dim= num_neurons,            # input features dimensionality
               num_kernels= nkernel,                 # number of kernels
               out_features_dim= output_dim,
               multifeature = True,
               radial_function=rbf_gaussian,  # radial basis function used
               norm_function=l_norm,
              ) 
        '''
        self.relu = nn.ReLU()
        self.inter = {}
        
    def forward(self, x):
        ln1out = self.ln1(x)
        self.inter['ln1'] = ln1out
        ln1out = self.nm1(ln1out)
        #ln1out = self.drop1(ln1out)

        device = ln1out.device
        batch_size, _ = x.size()
        
        # # # # # # # # # # # # # #
        #         SPLINE 1        #
        # # # # # # # # # # # # # #
        
        sp1out = self.sp1(ln1out)
        bslist = self.sp1.inter['basic']
        
        self.inter['ebasic'] = bslist
        self.inter['basic'] = sp1out

        #sp1out = self.drop2(sp1out)
        output = self.ln2(sp1out)
        #output = self.rbf(sp1out)
        #output = self.relu(output)
        return output

def num_para(model):
    tp = 0
    for param in model.parameters():
        tp += param.numel()
    return tp

# %%
nm = 100; dg = 3; L = 1; nk = 15; Fin = ndim; nkernel = 100; Fout = 1;
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")


MBS = MPSv3(input_dim = Fin, degree = dg, num_knots = nk, num_neurons = nm, output_dim = Fout, nkernel = nkernel, bias = True).to(device)
print('Number of Parameters: ', num_para(MBS))
# Out:
# Number of Parameters:  2701

# %% [markdown]
# ### Simulated data training

# %%
nm = 50; dg = 3; L = 1; nk = 15; Fin = ndim; nkernel = 100; Fout = 1;


MBS = MPSv3(input_dim = Fin, degree = dg, num_knots = nk, num_neurons = nm, output_dim = Fout, nkernel = nkernel, bias = True).to(device)

learning_r = 5e-2
criterion = torch.nn.MSELoss(reduction='mean')
optimizer = torch.optim.Adam(MBS.parameters(), lr=learning_r)

Iteration = 10000; bloss_list = []; tor = 1e-5; lr_tor = 1e-6
patientc = 10; patientr = 5; tpat = 0; bloss = 9999
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 nm = 50; dg = 3; L = 1; nk = 15; Fin = ndim; nkernel = 100; Fout = 1;
#       4 MBS = MPSv3(input_dim = Fin, degree = dg, num_knots = nk, num_neurons = nm, output_dim = Fout, nkernel = nkernel, bias = True).to(device)
#       6 learning_r = 5e-2
#
# NameError: name 'ndim' is not defined

# %%
d = 1
nm = 50; dg = 3; L = 1; nk = 15; Fin = ndim; nkernel = 200; Fout = 1;
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
MBS = MPSv3(input_dim = Fin, degree = dg, num_knots = nk, num_neurons = nm, output_dim = Fout, nkernel = nkernel, bias = True).to(device)
print('Number of Parameters: ', num_para(MBS))
learning_r = 1e-1
criterion = torch.nn.MSELoss(reduction='mean')
optimizer = torch.optim.Adam(MBS.parameters(), lr=learning_r)
Iteration = 10000; bloss_list = []; tor = 1e-5; lr_tor = 1e-6
patientc = 10; patientr = 5; tpat = 0; bloss = 9999

for t in range(Iteration):

    # Forward pass: Compute predicted y by passing x to the modelsp
    pyb_af = MBS(X_train)
    loss = criterion(y_train, pyb_af); bloss_list.append(loss.item())
    
    if (t > 0) and ((bloss_list[t-1]-bloss_list[t])<tor):        
        if (tpat != 0) and (tpat % patientr) == 0:
            learning_r *= 0.2 
            tpat += 1
            #print('Learning rate reduce to ', learning_r)
            optimizer = torch.optim.Adam(MBS.parameters(), lr=learning_r)
            if learning_r <= lr_tor:
                print('Convergence!')
                break
        elif tpat < patientc:
            tpat += 1
            pass
        else:
            print('Convergence!')
            break
        
    else:
        if loss < bloss:
            print('Current loss: ', loss.item(), ' | , previous best loss: ', bloss, ' | saving best model ...')
            torch.save(MBS.state_dict(), './EXA'+str(X_train.size()[0])+'h'+str(nm)+'k'+str(nk)+'data'+str(d+1))
            bloss = loss.item()
            tpat = 0
        else:
            tpat += 1

    if tpat == patientc:
        print('Convergence!')
        break
        
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()
    print('| Epoch: ',t+1,'/',str(Iteration),' | Loss: ', np.round(loss.item(), 4),' |')


with torch.no_grad():
    eval_model = MPSv3(input_dim = Fin, degree = dg, num_knots = nk, num_neurons = nm, output_dim = Fout, nkernel = nkernel, bias = True).to(device)
    eval_model.load_state_dict(torch.load('./EXA'+str(X_train.size()[0])+'h'+str(nm)+'k'+str(nk)+'data'+str(d+1), weights_only = True))
    print(criterion(y_test, eval_model(X_test).detach()))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 2
#       1 d = 1
# ----> 2 nm = 50; dg = 3; L = 1; nk = 10; Fin = ndim; nkernel = 200; Fout = 1;
#       3 device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
#       4 MBS = MPSv3(input_dim = Fin, degree = dg, num_knots = nk, num_neurons = nm, output_dim = Fout, nkernel = nkernel, bias = True).to(device)
#
# NameError: name 'ndim' is not defined

# %%
with torch.no_grad():
    eval_model = MPSv3(input_dim = Fin, degree = dg, num_knots = nk, num_neurons = nm, output_dim = Fout, nkernel = nkernel, bias = True).to(device)
    eval_model.load_state_dict(torch.load('./EXA'+str(X_train.size()[0])+'h'+str(nm)+'k'+str(nk)+'data'+str(d+1), weights_only = True))
    print(criterion(y_train, eval_model(X_train).detach()))
    plt.scatter(y_train, eval_model(X_train).detach())
# Out:
# tensor(0.0160)

# %%
with torch.no_grad():
    eval_model = MPSv3(input_dim = Fin, degree = dg, num_knots = nk, num_neurons = nm, output_dim = Fout, nkernel = nkernel, bias = True).to(device)
    eval_model.load_state_dict(torch.load('./EXA'+str(X_train.size()[0])+'h'+str(nm)+'k'+str(nk)+'data'+str(d+1), weights_only = True))
    print(criterion(y_test, eval_model(X_test).detach()))
    plt.scatter(y_test, eval_model(X_test).detach())
# Out:
# tensor(0.0818)

# %% [markdown]
# ## Tuning

# %%
with torch.no_grad():
    print('------------------------------------------')
    print('Before adding penalty ... ')
    eval_model = MPSv3(input_dim = Fin, degree = dg, num_knots = nk, num_neurons = nm, output_dim = Fout, nkernel = nkernel, bias = True).to(device)
    eval_model.load_state_dict(torch.load('./EXA'+str(X_train.size()[0])+'h'+str(nm)+'k'+str(nk)+'data'+str(d+1), weights_only = True))
    print('Training Error: ', np.round(criterion(y_train, eval_model(X_train).detach()).item(), 5), ' | Testing Error: ', np.round(criterion(y_test, eval_model(X_test).detach()).item(), 5))
    print('------------------------------------------')
    print('After adding penalty ... ')

    
    WB = eval_model.sp1.control_p
    DB = diag_mat_weights(WB.size()[0], 'second').to(device)
    BestGCV = 9999
    
    n = X_train.size()[0]

    WholeX = torch.cat((torch.ones((n,1)), X_train), dim = 1)
    for i in range(10):    
        MPSy = eval_model(X_train)
        
        # update first layer
        for node in range(nm):
            NLn1 = (torch.inverse(WholeX.T @ WholeX) @ WholeX.T) @ eval_model.inter['ln1'][:,node]
            getattr(eval_model.ln1, 'bias').data[node] = NLn1[0]
            getattr(eval_model.ln1, 'weight').data[node,:] = NLn1[1:]
            
        LambdaB1 = ECM(model = eval_model, num_neurons = nm, num_knots = nk, L = 1)        
        B1 = eval_model.inter['ebasic']
        P2 = (torch.linalg.pinv(B1.T @ B1) @ B1.T @ B1)
        
        By1 = eval_model.inter['basic']
        size1 = B1.size()[1]

        B1 = B1.view(nm, nk, size1)

        NW1 = torch.empty((nk, nm))
        NB1 = torch.empty((nm))
        for i in range(nm):
            B1y = By1[:,i] - eval_model.sp1.bias.data[i]
            BB1 = B1[i].T
            PB1 = (torch.linalg.pinv(BB1.T @ BB1) @ BB1.T @ BB1)

            # Update the weights and bias
            NW1[:, i] = (torch.inverse(BB1.T @ BB1 + (LambdaB1/size1) * (DB.T @ DB)) @ BB1.T @ B1y)
            NB1[i] = torch.mean(By1[:,i] - (NW1[:,i] @ BB1.T))
            
        # update the weight
        getattr(eval_model.sp1, 'control_p').data = NW1
        getattr(eval_model.sp1, 'bias').data = NB1

        # update the last layer
        WholeB = torch.cat((torch.ones((n,1)), By1), dim = 1)
        NLn2W = (torch.inverse(WholeB.T @ WholeB) @ WholeB.T @ y_train).T
        getattr(eval_model.ln2, 'bias').data = NLn2W[:,0]
        getattr(eval_model.ln2, 'weight').data = NLn2W[:,1:]

        MPSy = eval_model(X_train)
        trainloss = np.round(criterion(y_train, MPSy.detach()).item(), 5)
        GCV = np.round((torch.norm(y_train - MPSy)/(size1-torch.trace(P2))).item(), 5)
        
        if GCV < BestGCV:
            BestLambdaB = LambdaB1
            BestGCV = GCV
            
        MPSy = eval_model(X_test)
        print('Lambda: ', np.round(LambdaB1, 5),'| Training Loss: ', trainloss,'| GCV: ', GCV,' | Testing Error: ', np.round(criterion(y_test, MPSy.detach()).item(), 5))
# Out:
# ------------------------------------------
# Before adding penalty ...
# Training Error:  0.016  | Testing Error:  0.08184
# ------------------------------------------
# After adding penalty ...

# %% [markdown]
# ## Penalized Algorithm

# %%
for d in range(1,2):
    print('Dataset '+str(d+1))
    eval_model = MPSv3(input_dim = Fin, degree = dg, num_knots = nk, num_neurons = nm, output_dim = Fout, nkernel = nkernel, bias = True).to(device)
    eval_model.load_state_dict(torch.load( './EXA'+str(X_train.size()[0])+'h'+str(nm)+'k'+str(nk)+'data'+str(d+1), weights_only = True))
    optimizer = torch.optim.Adam(eval_model.parameters(), lr=1e-4)
    n = X_train.size()[0]
    bloss = 9999
    for t in range(1, 1001):
                                           
        # Forward pass: Compute predicted y by passing x to the modelsp
        pyb_af = eval_model(X_train)
        WB = eval_model.sp1.control_p
        DB = diag_mat_weights(WB.size()[0]).to(device)

        loss = criterion(y_train, pyb_af) + (BestLambdaB/n) * torch.norm(DB @ WB)
    
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        if loss < bloss:
            best_model = eval_model
            bloss = loss
        
        if t % 50 == 0:
            with torch.no_grad():
                print(criterion(y_test, eval_model(X_test).detach()).item())

with torch.no_grad():

    MBS = MPSv3(input_dim = Fin, degree = dg, num_knots = nk, num_neurons = nm, output_dim = Fout, nkernel = nkernel, bias = True).to(device)
    MBS.load_state_dict(torch.load( './EXA'+str(X_train.size()[0])+'h'+str(nm)+'k'+str(nk)+'data'+str(d+1), weights_only = True))
    MBSy = MBS(X_test)
    MPSy = best_model(X_test)
    print('MBS Testing Error: ', criterion(y_test, MBSy.detach()).item())
    print('MPS Testing Error: ', criterion(y_test, MPSy.detach()).item())

# %%
with torch.no_grad():
    train_true_space = torch.exp(y_train)
    test_true_space = torch.exp(y_test)
    train_pred_space = torch.exp(eval_model(X_train).detach())
    test_pred_space = torch.exp(eval_model(X_test).detach())

with torch.no_grad():
    print('Trainloss: ',criterion(train_true_space, train_pred_space).item(), ' | Testloss: ', criterion(test_true_space, test_pred_space).item())
    plt.subplot(1,2,1)
    plt.scatter(train_true_space, train_pred_space)
    plt.subplot(1,2,2)
    plt.scatter(test_true_space, test_pred_space)
    plt.show()

# %%
with torch.no_grad():
    MPSy = eval_model(X_train)
    t_np = eval_model.inter['basic'].numpy() #convert to Numpy array
    df = pd.DataFrame(t_np) #convert to a dataframe
    df.to_csv("output_feature.csv",index=False) #save to file
    
    t_np = y_train.numpy() #convert to Numpy array
    df = pd.DataFrame(t_np) #convert to a dataframe
    df.to_csv("output_eta.csv",index=False) #save to file

# %%
with torch.no_grad():
    MPSy = eval_model(X_test)
    t_np = eval_model.inter['basic'].numpy() #convert to Numpy array
    df = pd.DataFrame(t_np) #convert to a dataframe
    df.to_csv("test_output_feature.csv",index=False) #save to file
    
    t_np = y_test.numpy() #convert to Numpy array
    df = pd.DataFrame(t_np) #convert to a dataframe
    df.to_csv("test_output_eta.csv",index=False) #save to file

# %%
sample_test_beta[91]
sample_test_eta[91]
# Out:
# 0.01971603837716025

# %% [markdown]
# # Modeling 2-Spline

# %%
class MPSv3(nn.Module):
    def __init__(self, input_dim, degree, num_knots, num_neurons, output_dim, bias):
        super(MPSv3, self).__init__()
        self.num_neurons = num_neurons
        self.num_knots = num_knots
        self.ln1 = nn.Linear(input_dim, num_neurons)
        self.nm1 = NormLayer() 
        self.sp1 = PRODBSplineLayerMultiFeature(input_dim = 1, degree = degree, num_knots = num_knots, num_neurons = num_neurons, output_dim= output_dim, bias = True)
        self.nm2 = NormLayer() 
        self.sp2 = PRODBSplineLayerMultiFeature(input_dim = 1, degree = degree, num_knots = num_knots, num_neurons = num_neurons, output_dim= output_dim, bias = True)
        self.ln2 = nn.Linear(num_neurons, output_dim)
        #self.relu = nn.ReLU()
        self.drop1 = nn.Dropout(p=0.1)
        self.inter = {}
        
    def forward(self, x):
        ln1out = self.ln1(x)
        ln1out = self.nm1(ln1out)
        #ln1out = self.drop1(ln1out)
        
        device = ln1out.device
        batch_size, _ = x.size()
        
        # # # # # # # # # # # # # #
        #         SPLINE 1        #
        # # # # # # # # # # # # # #
        
        sp1out = self.sp1(ln1out)
        bslist = self.sp1.inter['basic']
        
        self.inter['ebasic'] = bslist
        self.inter['basic'] = sp1out

        # # # # # # # # # # # # # #
        #         SPLINE 1        #
        # # # # # # # # # # # # # #
        
        sp2out = self.sp2(ln1out)
        bslist2 = self.sp2.inter['basic']
        
        self.inter['ebasic2'] = bslist2
        self.inter['basic2'] = sp2out

        ln2out = self.ln2(sp2out)
        #ln2out = self.relu(ln2out)
        
        return ln2out

# %%
nm = 50; dg = 3; L = 1; nk = 15; Fin = ndim; Fout = 1;
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")


MBS = MPSv3(input_dim = Fin, degree = dg, num_knots = nk, num_neurons = nm, output_dim = Fout, bias = True).to(device)
print('Number of Parameters: ', num_para(MBS))

################################################
#        Example 3 use learning rate 1e-3      #
################################################
#    Example 1 and 2 use learning rate 1e-2    #
################################################

learning_r = 5e-2
criterion = torch.nn.MSELoss(reduction='mean')
optimizer = torch.optim.Adam(MBS.parameters(), lr=learning_r)

Iteration = 10000; bloss_list = []; tor = 1e-5; lr_tor = 1e-6
patientc = 10; patientr = 5; tpat = 0; bloss = 9999

for t in range(Iteration):

    # Forward pass: Compute predicted y by passing x to the modelsp
    pyb_af = MBS(X_train)
    loss = criterion(y_train, pyb_af); bloss_list.append(loss.item())
    
    if (t > 0) and ((bloss_list[t-1]-bloss_list[t])<tor):        
        if (tpat % patientr) == 0:
            learning_r *= 0.2 
            tpat += 1
            #print('Learning rate reduce to ', learning_r)
            optimizer = torch.optim.Adam(MBS.parameters(), lr=learning_r)
            if learning_r <= lr_tor:
                print('Convergence!')
                break
        elif tpat < patientc:
            tpat += 1
            pass
        else:
            print('Convergence!')
            break
        
    else:
        if loss < bloss:
            print('Current loss: ', loss.item(), ' | , previous best loss: ', bloss, ' | saving best model ...')
            torch.save(MBS.state_dict(), './1BestMBSn'+str(X_train.size()[0])+'h'+str(nm)+'k'+str(nk))
            bloss = loss.item()
            tpat = 0
        tpat += 1

    if tpat == patientc:
        print('Convergence!')
        break
        
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()
    #print('| Epoch: ',t+1,'/',str(Iteration),' | Loss: ', np.round(loss.item(), 4),' |')


with torch.no_grad():
    eval_model = MPSv3(input_dim = Fin, degree = dg, num_knots = nk, num_neurons = nm, output_dim = Fout, bias = True).to(device)
    eval_model.load_state_dict(torch.load('./1BestMBSn'+str(X_train.size()[0])+'h'+str(nm)+'k'+str(nk), weights_only = True))
    print(criterion(y_test, eval_model(X_test).detach()
# Current loss:  10.00667953491211  | , previous best loss:  10.127113342285156  | saving best model ...
# Current loss:  9.89609432220459  | , previous best loss:  10.00667953491211  | saving best model ...
# Current loss:  9.785741806030273  | , previous best loss:  9.89609432220459  | saving best model ...
# Current loss:  9.684332847595215  | , previous best loss:  9.785741806030273  | saving best model ...
# Current loss:  9.584527969360352  | , previous best loss:  9.684332847595215  | saving best model ...
# Current loss:  9.491960525512695  | , previous best loss:  9.584527969360352  | saving best model ...
# Current loss:  9.40241813659668  | , previous best loss:  9.491960525512695  | saving best model ...
# Current loss:  9.318039894104004  | , previous best loss:  9.40241813659668  | saving best model ...
# Current loss:  9.237276077270508  | , previous best loss:  9.318039894104004  | saving best model ...
# Current loss:  9.16003131866455  | , previous best loss:  9.237276077270508  | saving best model ...
# Current loss:  9.086803436279297  | , previous best loss:  9.16003131866455  | saving best model ...
# Current loss:  9.016297340393066  | , previous best loss:  9.086803436279297  | saving best model ...
# Current loss:  8.949856758117676  | , previous best loss:  9.016297340393066  | saving best model ...
# Current loss:  8.88550090789795  | , previous best loss:  8.949856758117676  | saving best model ...
# Current loss:  8.824822425842285  | , previous best loss:  8.88550090789795  | saving best model ...
# Current loss:  8.765799522399902  | , previous best loss:  8.824822425842285  | saving best model ...
# Current loss:  8.710061073303223  | , previous best loss:  8.765799522399902  | saving best model ...
# Current loss:  8.655765533447266  | , previous best loss:  8.710061073303223  | saving best model ...
# Current loss:  8.604304313659668  | , previous best loss:  8.655765533447266  | saving best model ...
# Current loss:  8.554059028625488  | , previous best loss:  8.604304313659668  | saving best model ...
# Current loss:  8.5061616897583  | , previous best loss:  8.554059028625488  | saving best model ...
# Current loss:  8.459342956542969  | , previous best loss:  8.5061616897583  | saving best model ...
# Current loss:  8.414461135864258  | , previous best loss:  8.459342956542969  | saving best model ...
# Current loss:  8.370528221130371  | , previous best loss:  8.414461135864258  | saving best model ...
# Current loss:  8.328076362609863  | , previous best loss:  8.370528221130371  | saving best model ...
# Current loss:  8.286465644836426  | , previous best loss:  8.328076362609863  | saving best model ...
# Current loss:  8.246007919311523  | , previous best loss:  8.286465644836426  | saving best model ...
# Current loss:  8.20644760131836  | , previous best loss:  8.246007919311523  | saving best model ...
# Current loss:  8.167835235595703  | , previous best loss:  8.20644760131836  | saving best model ...
# Current loss:  8.130182266235352  | , previous best loss:  8.167835235595703  | saving best model ...
# Current loss:  8.093297004699707  | , previous best loss:  8.130182266235352  | saving best model ...
# Current loss:  8.05742073059082  | , previous best loss:  8.093297004699707  | saving best model ...
# Current loss:  8.02220630645752  | , previous best loss:  8.05742073059082  | saving best model ...
# Current loss:  7.98802375793457  | , previous best loss:  8.02220630645752  | saving best model ...
# Current loss:  7.954440593719482  | , previous best loss:  7.98802375793457  | saving best model ...
# Current loss:  7.921830177307129  | , previous best loss:  7.954440593719482  | saving best model ...
# Current loss:  7.889817237854004  | , previous best loss:  7.921830177307129  | saving best model ...
# Current loss:  7.858685493469238  | , previous best loss:  7.889817237854004  | saving best model ...
# Current loss:  7.8281941413879395  | , previous best loss:  7.858685493469238  | saving best model ...
# Current loss:  6.971965789794922  | , previous best loss:  6.988645076751709  | saving best model ...
# Current loss:  6.955474376678467  | , previous best loss:  6.971965789794922  | saving best model ...
# Current loss:  6.939161777496338  | , previous best loss:  6.955474376678467  | saving best model ...
# Current loss:  6.923022270202637  | , previous best loss:  6.939161777496338  | saving best model ...
# Current loss:  6.907054424285889  | , previous best loss:  6.923022270202637  | saving best model ...
# Current loss:  6.891253471374512  | , previous best loss:  6.907054424285889  | saving best model ...
# Current loss:  6.875612735748291  | , previous best loss:  6.891253471374512  | saving best model ...
# Current loss:  6.860132217407227  | , previous best loss:  6.875612735748291  | saving best model ...
# Current loss:  6.844803333282471  | , previous best loss:  6.860132217407227  | saving best model ...
# Current loss:  6.82962703704834  | , previous best loss:  6.844803333282471  | saving best model ...
# Current loss:  6.8145952224731445  | , previous best loss:  6.82962703704834  | saving best model ...
# Current loss:  6.799709320068359  | , previous best loss:  6.8145952224731445  | saving best model ...
# Current loss:  6.784962177276611  | , previous best loss:  6.799709320068359  | saving best model ...
# Current loss:  6.770354270935059  | , previous best loss:  6.784962177276611  | saving best model ...
# Current loss:  6.75587797164917  | , previous best loss:  6.770354270935059  | saving best model ...
# Current loss:  6.741534233093262  | , previous best loss:  6.75587797164917  | saving best model ...
# Current loss:  6.7273173332214355  | , previous best loss:  6.741534233093262  | saving best model ...
# Current loss:  6.713225364685059  | , previous best loss:  6.7273173332214355  | saving best model ...
# Current loss:  6.699256896972656  | , previous best loss:  6.713225364685059  | saving best model ...
# Current loss:  6.685410022735596  | , previous best loss:  6.699256896972656  | saving best model ...
# Current loss:  6.671680450439453  | , previous best loss:  6.685410022735596  | saving best model ...
# Current loss:  6.65806770324707  | , previous best loss:  6.671680450439453  | saving best model ...
# Current loss:  6.644569396972656  | , previous best loss:  6.65806770324707  | saving best model ...
# Current loss:  6.631181240081787  | , previous best loss:  6.644569396972656  | saving best model ...
# Current loss:  6.617903709411621  | , previous best loss:  6.631181240081787  | saving best model ...
# Current loss:  6.604735374450684  | , previous best loss:  6.617903709411621  | saving best model ...
# Current loss:  6.591673374176025  | , previous best loss:  6.604735374450684  | saving best model ...
# Current loss:  6.578717231750488  | , previous best loss:  6.591673374176025  | saving best model ...
# Current loss:  6.5658650398254395  | , previous best loss:  6.578717231750488  | saving best model ...
# Current loss:  6.553116798400879  | , previous best loss:  6.5658650398254395  | saving best model ...
# Current loss:  6.540468215942383  | , previous best loss:  6.553116798400879  | saving best model ...
# Current loss:  6.527924060821533  | , previous best loss:  6.540468215942383  | saving best model ...
# Current loss:  6.515477657318115  | , previous best loss:  6.527924060821533  | saving best model ...
# Current loss:  6.5031304359436035  | , previous best loss:  6.515477657318115  | saving best model ...
# Current loss:  6.490882873535156  | , previous best loss:  6.5031304359436035  | saving best model ...
# Current loss:  6.478733062744141  | , previous best loss:  6.490882873535156  | saving best model ...
# Current loss:  6.466681003570557  | , previous best loss:  6.478733062744141  | saving best model ...
# Current loss:  6.45472526550293  | , previous best loss:  6.466681003570557  | saving best model ...
# Current loss:  6.442866325378418  | , previous best loss:  6.45472526550293  | saving best model ...
# Current loss:  6.431106090545654  | , previous best loss:  6.442866325378418  | saving best model ...
# Current loss:  6.419439315795898  | , previous best loss:  6.431106090545654  | saving best model ...
# Current loss:  6.4078688621521  | , previous best loss:  6.419439315795898  | saving best model ...
# Current loss:  6.396394729614258  | , previous best loss:  6.4078688621521  | saving best model ...
# Current loss:  6.385016918182373  | , previous best loss:  6.396394729614258  | saving best model ...
# Current loss:  6.373735427856445  | , previous best loss:  6.385016918182373  | saving best model ...
# Current loss:  6.362546920776367  | , previous best loss:  6.373735427856445  | saving best model ...
# Current loss:  6.351457118988037  | , previous best loss:  6.362546920776367  | saving best model ...
# Current loss:  6.340458869934082  | , previous best loss:  6.351457118988037  | saving best model ...
# Current loss:  6.329556465148926  | , previous best loss:  6.340458869934082  | saving best model ...
# Current loss:  6.3187479972839355  | , previous best loss:  6.329556465148926  | saving best model ...
# Current loss:  6.3080363273620605  | , previous best loss:  6.3187479972839355  | saving best model ...
# Current loss:  6.297417163848877  | , previous best loss:  6.3080363273620605  | saving best model ...
# Current loss:  6.286892890930176  | , previous best loss:  6.297417163848877  | saving best model ...
# Current loss:  6.276462078094482  | , previous best loss:  6.286892890930176  | saving best model ...
# Current loss:  6.266125202178955  | , previous best loss:  6.276462078094482  | saving best model ...
# Current loss:  6.2558794021606445  | , previous best loss:  6.266125202178955  | saving best model ...
# Current loss:  6.245726585388184  | , previous best loss:  6.2558794021606445  | saving best model ...
# Current loss:  6.235666275024414  | , previous best loss:  6.245726585388184  | saving best model ...
# Current loss:  6.225697040557861  | , previous best loss:  6.235666275024414  | saving best model ...
# Current loss:  6.215819835662842  | , previous best loss:  6.225697040557861  | saving best model ...
# Current loss:  6.206032752990723  | , previous best loss:  6.215819835662842  | saving best model ...
# Current loss:  6.196335315704346  | , previous best loss:  6.206032752990723  | saving best model ...
# Current loss:  6.1867265701293945  | , previous best loss:  6.196335315704346  | saving best model ...
# Current loss:  6.177206039428711  | , previous best loss:  6.1867265701293945  | saving best model ...
# Current loss:  6.1677751541137695  | , previous best loss:  6.177206039428711  | saving best model ...
# Current loss:  6.158430099487305  | , previous best loss:  6.1677751541137695  | saving best model ...
# Current loss:  6.149171829223633  | , previous best loss:  6.158430099487305  | saving best model ...
# Current loss:  6.140000343322754  | , previous best loss:  6.149171829223633  | saving best model ...
# Current loss:  6.130913734436035  | , previous best loss:  6.140000343322754  | saving best model ...
# Current loss:  6.121913909912109  | , previous best loss:  6.130913734436035  | saving best model ...
# Current loss:  6.112998962402344  | , previous best loss:  6.121913909912109  | saving best model ...
# Current loss:  6.1041789054870605  | , previous best loss:  6.112998962402344  | saving best model ...
# Current loss:  6.095464706420898  | , previous best loss:  6.1041789054870605  | saving best model ...
# Current loss:  6.086897373199463  | , previous best loss:  6.095464706420898  | saving best model ...
# Current loss:  6.07858943939209  | , previous best loss:  6.086897373199463  | saving best model ...
# Current loss:  6.070854663848877  | , previous best loss:  6.07858943939209  | saving best model ...
# Current loss:  5.513948440551758  | , previous best loss:  5.517640590667725  | saving best model ...
# Current loss:  5.510287284851074  | , previous best loss:  5.513948440551758  | saving best model ...
# Current loss:  5.506651878356934  | , previous best loss:  5.510287284851074  | saving best model ...
# Current loss:  5.503044605255127  | , previous best loss:  5.506651878356934  | saving best model ...
# Current loss:  5.499461650848389  | , previous best loss:  5.503044605255127  | saving best model ...
# Current loss:  5.495904445648193  | , previous best loss:  5.499461650848389  | saving best model ...
# Current loss:  5.492371559143066  | , previous best loss:  5.495904445648193  | saving best model ...
# Current loss:  5.488866329193115  | , previous best loss:  5.492371559143066  | saving best model ...
# Current loss:  5.485391139984131  | , previous best loss:  5.488866329193115  | saving best model ...
# Current loss:  5.48195219039917  | , previous best loss:  5.485391139984131  | saving best model ...
# Current loss:  5.47856330871582  | , previous best loss:  5.48195219039917  | saving best model ...
# Current loss:  5.475245952606201  | , previous best loss:  5.47856330871582  | saving best model ...
# Current loss:  5.472053527832031  | , previous best loss:  5.475245952606201  | saving best model ...
# Current loss:  5.4690842628479  | , previous best loss:  5.472053527832031  | saving best model ...
# Current loss:  5.466550350189209  | , previous best loss:  5.4690842628479  | saving best model ...
# Current loss:  5.464904308319092  | , previous best loss:  5.466550350189209  | saving best model ...
# Convergence!
# tensor(13.7425)

# %%
with torch.no_grad():
    eval_model = MPSv3(input_dim = Fin, degree = dg, num_knots = nk, num_neurons = nm, output_dim = Fout, bias = True).to(device)
    eval_model.load_state_dict(torch.load('./1BestMBSn'+str(X_train.size()[0])+'h'+str(nm)+'k'+str(nk), weights_only = True))
    print(criterion(y_test, eval_model(X_test).detach()))
    plt.scatter(y_test, eval_model(X_test).detach())
# Out:
# tensor(13.7425)

# %% [markdown]
# ### Penalized model

# %%
with torch.no_grad():
    print('------------------------------------------')
    print('Before adding penalty ... ')
    eval_model = MPSv3(input_dim = Fin, degree = dg, num_knots = nk, num_neurons = nm, output_dim = Fout, bias = True).to(device)
    eval_model.load_state_dict(torch.load('./1BestMBSn'+str(X_train.size()[0])+'h'+str(nm)+'k'+str(nk), weights_only = True))
    print('Training Error: ', np.round(criterion(y_train, eval_model(X_train).detach()).item(), 5), ' | Testing Error: ', np.round(criterion(y_test, eval_model(X_test).detach()).item(), 5))
    print('------------------------------------------')
    print('After adding penalty ... ')

    
    WB = eval_model.sp1.control_p
    DB = diag_mat_weights(WB.size()[0], 'second').to(device)
    BestGCV = 9999
    
    for i in range(10):
        MPSy = eval_model(X_train)
        LambdaB1 = ECM(model = eval_model, num_neurons = nm, num_knots = nk, L = 1)
        LambdaB2 = ECM(model = eval_model, num_neurons = nm, num_knots = nk, L = 2)
        
        B1 = eval_model.inter['ebasic']
        B2 = eval_model.inter['ebasic2']
        P2 = (torch.linalg.pinv(B2.T @ B2) @ B2.T @ B2)
        
        By1 = eval_model.inter['basic']
        By2 = eval_model.inter['basic2']
        
        size1 = B1.size()[1]
        size2 = B2.size()[1]

        B1 = B1.view(nm, nk, size1)
        B2 = B2.view(nm, nk, size2)

        NW1 = torch.empty((nk, nm))
        NW2 = torch.empty((nk, nm))
        NB1 = torch.empty((nm))
        NB2 = torch.empty((nm))
        for i in range(nm):
            B1y = By1[:,i] - eval_model.sp1.bias.data[i]
            B2y = By2[:,i] - eval_model.sp2.bias.data[i]

            BB1 = B1[i].T
            BB2 = B2[i].T
            PB1 = (torch.linalg.pinv(BB1.T @ BB1) @ BB1.T @ BB1)
            PB2 = (torch.linalg.pinv(BB2.T @ BB2) @ BB2.T @ BB2)

            # Update the weights and bias
            NW1[:, i] = (torch.inverse(BB1.T @ BB1 + (LambdaB1/size1) * (DB.T @ DB)) @ BB1.T @ B1y)
            NW2[:, i] = (torch.inverse(BB2.T @ BB2 + (LambdaB2/size2) * (DB.T @ DB)) @ BB2.T @ B2y)
            NB1[i] = torch.mean(By1[:,i] - (NW1[:,i] @ BB1.T))
            NB2[i] = torch.mean(By2[:,i] - (NW2[:,i] @ BB2.T))
            
        # update the weight
        getattr(eval_model.sp1, 'control_p').data = NW1
        getattr(eval_model.sp2, 'control_p').data = NW2
        getattr(eval_model.sp1, 'bias').data = NB1
        getattr(eval_model.sp2, 'bias').data = NB2
        

        MPSy = eval_model(X_train)
        trainloss = np.round(criterion(y_train, MPSy.detach()).item(), 5)
        GCV = np.round((torch.norm(y_train - MPSy)/(size2-torch.trace(P2))).item(), 5)
        
        if GCV < BestGCV:
            BestLambdaB1, BestLambdaB2 = LambdaB1, LambdaB2
            BestGCV = GCV
            
        MPSy = eval_model(X_test)
        print('Lambda: ', np.round(LambdaB1, 5),' and ', np.round(LambdaB2, 5),'| Training Loss: ', trainloss,'| GCV: ', GCV,' | Testing Error: ', np.round(criterion(y_test, MPSy.detach()).item(), 5))

# %%
nm = 50; dg = 3; L = 1; nk = 10; Fin = ndim; Fout = 1;

eval_model = MPSv3(input_dim = Fin, degree = dg, num_knots = nk, num_neurons = nm, output_dim = Fout, bias = True).to(device)
eval_model.load_state_dict(torch.load('./1BestMBSn'+str(X_train.size()[0])+'h'+str(nm)+'k'+str(nk), weights_only = True))


################################################
#        Example 3 use learning rate 1e-3      #
################################################
#    Example 1 and 2 use learning rate 1e-2    #
################################################
learning_r = 1e-3

criterion = torch.nn.MSELoss(reduction='mean')
optimizer = torch.optim.Adam(eval_model.parameters(), lr=learning_r)

fast_tune = 1001; bloss_list = []; tor = 1e-5; lr_tor = 1e-6
patientc = 10; patientr = 5; tpat = 0; bloss = 9999
n = X_train.size()[0]

for t in range(1, fast_tune):

    # Forward pass: Compute predicted y by passing x to the modelsp
    pyb_af = eval_model(X_train)
    WB1 = eval_model.sp1.control_p.data; WB2 = eval_model.sp2.control_p.data
    DB1 = diag_mat_weights(WB1.size()[0]).to(device); DB2 = diag_mat_weights(WB2.size()[0]).to(device)

    loss = criterion(y_train, pyb_af) + (BestLambdaB1/n) * torch.norm(DB1 @ WB1) + (BestLambdaB2/n) * torch.norm(DB2 @ WB2)
    bloss_list.append(loss.item())

    '''
    if (t > 0) and ((bloss_list[t-1]-bloss_list[t])<tor):        
        if (tpat % patientr) == 0:
            learning_r *= 0.2 
            tpat += 1
            #print('Learning rate reduce to ', learning_r)
            optimizer = torch.optim.Adam(MBS.parameters(), lr=learning_r)
            if learning_r <= lr_tor:
                print('Convergence!')
                break
        elif tpat < patientc:
            tpat += 1
            pass
        else:
            print('Convergence!')
            break
        
    else:
        if loss < bloss:
            print('Current loss: ', loss.item(), ' | , previous best loss: ', bloss, ' | saving best model ...')
            torch.save(MBS.state_dict(), './1BestMBSn'+str(X_train.size()[0])+'h'+str(nm)+'k'+str(nk))
            bloss = loss.item()
            tpat = 0
        tpat += 1

    if tpat == patientc:
        print('Convergence!')
        break
    '''
    
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()

    if t % 100 == 0:
        with torch.no_grad():
            print(criterion(y_test, eval_model(X_test).detach()))
            
    #print('| Epoch: ',t+1,'/',str(Iteration),' | Loss: ', np.round(loss.item(), 4),' |')


with torch.no_grad():
    print(criterion(y_test, eval_model(X_test).detach()))
# Out:
# tensor(0.0006)
# tensor(0.0004)
# tensor(0.0003)
# tensor(0.0003)
# tensor(0.0002)
# tensor(0.0002)
# tensor(0.0002)
# tensor(0.0001)
# tensor(0.0001)
# tensor(0.0001)
# tensor(0.0001)

# %% [markdown]
# # Multi-Linear

# %%
class MLNet(nn.Module):
    def __init__(self, input_dim, output_dim):
        super(MLNet, self).__init__()
        self.ln1 = nn.Linear(input_dim, 30)
        self.relu1 = nn.ReLU()
        self.ln2 = nn.Linear(30, 30)
        self.relu2 = nn.ReLU()
        self.ln3 = nn.Linear(30, output_dim)
        self.relu3 = nn.ReLU()
        
    def forward(self, x):
        x = self.ln1(x)
        x = self.relu1(x)
        x = self.ln2(x)
        x = self.relu2(x)
        x = self.ln3(x)
        output = self.relu3(x)
        
        return output

# %%
ML = MLNet(ndim, 1)
print('Number of parameter: ', num_para(ML))
learning_r = 1e-4
criterion = torch.nn.MSELoss(reduction='mean')
optimizer = torch.optim.Adam(ML.parameters(), lr=learning_r)
Iteration = 10000; bloss_list = []; tor = 1e-5; lr_tor = 1e-6
patientc = 10; patientr = 5; tpat = 0; bloss = 9999

for t in range(Iteration):

    # Forward pass: Compute predicted y by passing x to the modelsp
    pyb_af = ML(X_train)
    loss = criterion(y_train, pyb_af); bloss_list.append(loss.item())
    
    if (t > 0) and ((bloss_list[t-1]-bloss_list[t])<tor):        
        if (tpat % patientr) == 0:
            learning_r *= 0.2 
            tpat += 1
            #print('Learning rate reduce to ', learning_r)
            optimizer = torch.optim.Adam(ML.parameters(), lr=learning_r)
            if learning_r <= lr_tor:
                print('Convergence!')
                break
        elif tpat < patientc:
            tpat += 1
            pass
        else:
            print('Convergence!')
            break
        
    else:
        if loss < bloss:
            print('Current loss: ', loss.item(), ' | , previous best loss: ', bloss, ' | saving best model ...')
            #torch.save(MBS.state_dict(), './EXA'+str(X_train.size()[0])+'h'+str(nm)+'k'+str(nk)+'data'+str(d+1))
            bloss = loss.item()
            tpat = 0
        tpat += 1

    if tpat == patientc:
        print('Convergence!')
        break
        
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()
    print('| Epoch: ',t+1,'/',str(Iteration),' | Loss: ', np.round(loss.item(), 4),' |')
# Out:
# Current loss:  0.5207098126411438  | , previous best loss:  9999  | saving best model ...
# | Epoch:  1 / 10000  | Loss:  0.5207  |
# Current loss:  0.5193433165550232  | , previous best loss:  0.5207098126411438  | saving best model ...
# | Epoch:  2 / 10000  | Loss:  0.5193  |
# Current loss:  0.5179778337478638  | , previous best loss:  0.5193433165550232  | saving best model ...
# | Epoch:  3 / 10000  | Loss:  0.518  |
# Current loss:  0.5166123509407043  | , previous best loss:  0.5179778337478638  | saving best model ...
# | Epoch:  4 / 10000  | Loss:  0.5166  |
# Current loss:  0.5152472853660583  | , previous best loss:  0.5166123509407043  | saving best model ...
# | Epoch:  5 / 10000  | Loss:  0.5152  |
# Current loss:  0.5138829350471497  | , previous best loss:  0.5152472853660583  | saving best model ...
# | Epoch:  6 / 10000  | Loss:  0.5139  |
# Current loss:  0.5125197768211365  | , previous best loss:  0.5138829350471497  | saving best model ...
# | Epoch:  7 / 10000  | Loss:  0.5125  |
# Current loss:  0.511157214641571  | , previous best loss:  0.5125197768211365  | saving best model ...
# | Epoch:  8 / 10000  | Loss:  0.5112  |
# Current loss:  0.5097959041595459  | , previous best loss:  0.511157214641571  | saving best model ...
# | Epoch:  9 / 10000  | Loss:  0.5098  |
# Current loss:  0.5084351897239685  | , previous best loss:  0.5097959041595459  | saving best model ...
# | Epoch:  10 / 10000  | Loss:  0.5084  |
# Current loss:  0.5070756673812866  | , previous best loss:  0.5084351897239685  | saving best model ...
# | Epoch:  11 / 10000  | Loss:  0.5071  |
# Current loss:  0.5057170987129211  | , previous best loss:  0.5070756673812866  | saving best model ...
# | Epoch:  12 / 10000  | Loss:  0.5057  |
# Current loss:  0.5043598413467407  | , previous best loss:  0.5057170987129211  | saving best model ...
# | Epoch:  13 / 10000  | Loss:  0.5044  |
# Current loss:  0.5030036568641663  | , previous best loss:  0.5043598413467407  | saving best model ...
# | Epoch:  14 / 10000  | Loss:  0.503  |
# Current loss:  0.501648485660553  | , previous best loss:  0.5030036568641663  | saving best model ...
# | Epoch:  15 / 10000  | Loss:  0.5016  |
# Current loss:  0.5002936720848083  | , previous best loss:  0.501648485660553  | saving best model ...
# | Epoch:  16 / 10000  | Loss:  0.5003  |
# Current loss:  0.4989391267299652  | , previous best loss:  0.5002936720848083  | saving best model ...
# | Epoch:  17 / 10000  | Loss:  0.4989  |
# Current loss:  0.4975847899913788  | , previous best loss:  0.4989391267299652  | saving best model ...
# | Epoch:  18 / 10000  | Loss:  0.4976  |
# Current loss:  0.4962307810783386  | , previous best loss:  0.4975847899913788  | saving best model ...
# | Epoch:  19 / 10000  | Loss:  0.4962  |
# Current loss:  0.494877427816391  | , previous best loss:  0.4962307810783386  | saving best model ...
# | Epoch:  20 / 10000  | Loss:  0.4949  |
# Current loss:  0.4935249388217926  | , previous best loss:  0.494877427816391  | saving best model ...
# | Epoch:  21 / 10000  | Loss:  0.4935  |
# Current loss:  0.49217289686203003  | , previous best loss:  0.4935249388217926  | saving best model ...
# | Epoch:  22 / 10000  | Loss:  0.4922  |
# Current loss:  0.49082115292549133  | , previous best loss:  0.49217289686203003  | saving best model ...
# | Epoch:  23 / 10000  | Loss:  0.4908  |
# Current loss:  0.4894697964191437  | , previous best loss:  0.49082115292549133  | saving best model ...
# | Epoch:  24 / 10000  | Loss:  0.4895  |
# Current loss:  0.48811832070350647  | , previous best loss:  0.4894697964191437  | saving best model ...
# | Epoch:  25 / 10000  | Loss:  0.4881  |
# Current loss:  0.4867667257785797  | , previous best loss:  0.48811832070350647  | saving best model ...
# | Epoch:  26 / 10000  | Loss:  0.4868  |
# Current loss:  0.4854156970977783  | , previous best loss:  0.4867667257785797  | saving best model ...
# | Epoch:  27 / 10000  | Loss:  0.4854  |
# Current loss:  0.48406440019607544  | , previous best loss:  0.4854156970977783  | saving best model ...
# | Epoch:  28 / 10000  | Loss:  0.4841  |
# Current loss:  0.48271283507347107  | , previous best loss:  0.48406440019607544  | saving best model ...
# | Epoch:  29 / 10000  | Loss:  0.4827  |
# Current loss:  0.48136183619499207  | , previous best loss:  0.48271283507347107  | saving best model ...
# | Epoch:  30 / 10000  | Loss:  0.4814  |
# Current loss:  0.48001158237457275  | , previous best loss:  0.48136183619499207  | saving best model ...
# | Epoch:  31 / 10000  | Loss:  0.48  |
# Current loss:  0.47866150736808777  | , previous best loss:  0.48001158237457275  | saving best model ...
# | Epoch:  32 / 10000  | Loss:  0.4787  |
# Current loss:  0.4773114323616028  | , previous best loss:  0.47866150736808777  | saving best model ...
# | Epoch:  33 / 10000  | Loss:  0.4773  |
# Current loss:  0.47596240043640137  | , previous best loss:  0.4773114323616028  | saving best model ...
# | Epoch:  34 / 10000  | Loss:  0.476  |
# Current loss:  0.4746134579181671  | , previous best loss:  0.47596240043640137  | saving best model ...
# | Epoch:  35 / 10000  | Loss:  0.4746  |
# Current loss:  0.4732641875743866  | , previous best loss:  0.4746134579181671  | saving best model ...
# | Epoch:  36 / 10000  | Loss:  0.4733  |
# Current loss:  0.47191452980041504  | , previous best loss:  0.4732641875743866  | saving best model ...
# | Epoch:  37 / 10000  | Loss:  0.4719  |
# Current loss:  0.47056445479393005  | , previous best loss:  0.47191452980041504  | saving best model ...
# | Epoch:  38 / 10000  | Loss:  0.4706  |
# Current loss:  0.4692147374153137  | , previous best loss:  0.47056445479393005  | saving best model ...
# | Epoch:  39 / 10000  | Loss:  0.4692  |
# Current loss:  0.46786564588546753  | , previous best loss:  0.4692147374153137  | saving best model ...
# | Epoch:  40 / 10000  | Loss:  0.4679  |
# Current loss:  0.4665165841579437  | , previous best loss:  0.46786564588546753  | saving best model ...
# | Epoch:  41 / 10000  | Loss:  0.4665  |
# Current loss:  0.46516701579093933  | , previous best loss:  0.4665165841579437  | saving best model ...
# | Epoch:  42 / 10000  | Loss:  0.4652  |
# Current loss:  0.463817298412323  | , previous best loss:  0.46516701579093933  | saving best model ...
# | Epoch:  43 / 10000  | Loss:  0.4638  |
# Current loss:  0.4624673128128052  | , previous best loss:  0.463817298412323  | saving best model ...
# | Epoch:  44 / 10000  | Loss:  0.4625  |
# Current loss:  0.46111729741096497  | , previous best loss:  0.4624673128128052  | saving best model ...
# | Epoch:  45 / 10000  | Loss:  0.4611  |
# Current loss:  0.4597669243812561  | , previous best loss:  0.46111729741096497  | saving best model ...
# | Epoch:  46 / 10000  | Loss:  0.4598  |
# Current loss:  0.45841681957244873  | , previous best loss:  0.4597669243812561  | saving best model ...
# | Epoch:  47 / 10000  | Loss:  0.4584  |
# Current loss:  0.45706695318222046  | , previous best loss:  0.45841681957244873  | saving best model ...
# | Epoch:  48 / 10000  | Loss:  0.4571  |
# Current loss:  0.45571720600128174  | , previous best loss:  0.45706695318222046  | saving best model ...
# | Epoch:  49 / 10000  | Loss:  0.4557  |
# Current loss:  0.45436641573905945  | , previous best loss:  0.45571720600128174  | saving best model ...
# | Epoch:  50 / 10000  | Loss:  0.4544  |
# Current loss:  0.45301520824432373  | , previous best loss:  0.45436641573905945  | saving best model ...
# | Epoch:  51 / 10000  | Loss:  0.453  |
# Current loss:  0.451663613319397  | , previous best loss:  0.45301520824432373  | saving best model ...
# | Epoch:  96 / 10000  | Loss:  0.3917  |
# Current loss:  0.3903728127479553  | , previous best loss:  0.3917425572872162  | saving best model ...
# | Epoch:  97 / 10000  | Loss:  0.3904  |
# Current loss:  0.3890024423599243  | , previous best loss:  0.3903728127479553  | saving best model ...
# | Epoch:  98 / 10000  | Loss:  0.389  |
# Current loss:  0.38763245940208435  | , previous best loss:  0.3890024423599243  | saving best model ...
# | Epoch:  99 / 10000  | Loss:  0.3876  |
# Current loss:  0.38626205921173096  | , previous best loss:  0.38763245940208435  | saving best model ...
# | Epoch:  100 / 10000  | Loss:  0.3863  |
# Current loss:  0.38489148020744324  | , previous best loss:  0.38626205921173096  | saving best model ...
# | Epoch:  101 / 10000  | Loss:  0.3849  |
# Current loss:  0.3835202157497406  | , previous best loss:  0.38489148020744324  | saving best model ...
# | Epoch:  102 / 10000  | Loss:  0.3835  |
# Current loss:  0.38214749097824097  | , previous best loss:  0.3835202157497406  | saving best model ...
# | Epoch:  103 / 10000  | Loss:  0.3821  |
# Current loss:  0.3807740807533264  | , previous best loss:  0.38214749097824097  | saving best model ...
# | Epoch:  104 / 10000  | Loss:  0.3808  |
# Current loss:  0.37940070033073425  | , previous best loss:  0.3807740807533264  | saving best model ...
# | Epoch:  105 / 10000  | Loss:  0.3794  |
# Current loss:  0.37802669405937195  | , previous best loss:  0.37940070033073425  | saving best model ...
# | Epoch:  106 / 10000  | Loss:  0.378  |
# Current loss:  0.3766525387763977  | , previous best loss:  0.37802669405937195  | saving best model ...
# | Epoch:  107 / 10000  | Loss:  0.3767  |
# Current loss:  0.3752783536911011  | , previous best loss:  0.3766525387763977  | saving best model ...
# | Epoch:  108 / 10000  | Loss:  0.3753  |
# Current loss:  0.37390315532684326  | , previous best loss:  0.3752783536911011  | saving best model ...
# | Epoch:  109 / 10000  | Loss:  0.3739  |
# Current loss:  0.3725273013114929  | , previous best loss:  0.37390315532684326  | saving best model ...
# | Epoch:  110 / 10000  | Loss:  0.3725  |
# Current loss:  0.371150940656662  | , previous best loss:  0.3725273013114929  | saving best model ...
# | Epoch:  111 / 10000  | Loss:  0.3712  |
# Current loss:  0.3697740137577057  | , previous best loss:  0.371150940656662  | saving best model ...
# | Epoch:  112 / 10000  | Loss:  0.3698  |
# Current loss:  0.3683972656726837  | , previous best loss:  0.3697740137577057  | saving best model ...
# | Epoch:  113 / 10000  | Loss:  0.3684  |
# Current loss:  0.36702069640159607  | , previous best loss:  0.3683972656726837  | saving best model ...
# | Epoch:  114 / 10000  | Loss:  0.367  |
# Current loss:  0.3656438887119293  | , previous best loss:  0.36702069640159607  | saving best model ...
# | Epoch:  115 / 10000  | Loss:  0.3656  |
# Current loss:  0.36426666378974915  | , previous best loss:  0.3656438887119293  | saving best model ...
# | Epoch:  116 / 10000  | Loss:  0.3643  |
# Current loss:  0.36288943886756897  | , previous best loss:  0.36426666378974915  | saving best model ...
# | Epoch:  117 / 10000  | Loss:  0.3629  |
# Current loss:  0.36151179671287537  | , previous best loss:  0.36288943886756897  | saving best model ...
# | Epoch:  118 / 10000  | Loss:  0.3615  |
# Current loss:  0.36013340950012207  | , previous best loss:  0.36151179671287537  | saving best model ...
# | Epoch:  119 / 10000  | Loss:  0.3601  |
# Current loss:  0.3587539792060852  | , previous best loss:  0.36013340950012207  | saving best model ...
# | Epoch:  120 / 10000  | Loss:  0.3588  |
# Current loss:  0.3573739528656006  | , previous best loss:  0.3587539792060852  | saving best model ...
# | Epoch:  121 / 10000  | Loss:  0.3574  |
# Current loss:  0.3559934198856354  | , previous best loss:  0.3573739528656006  | saving best model ...
# | Epoch:  122 / 10000  | Loss:  0.356  |
# Current loss:  0.35461166501045227  | , previous best loss:  0.3559934198856354  | saving best model ...
# | Epoch:  123 / 10000  | Loss:  0.3546  |
# Current loss:  0.35322943329811096  | , previous best loss:  0.35461166501045227  | saving best model ...
# | Epoch:  124 / 10000  | Loss:  0.3532  |
# Current loss:  0.3518472909927368  | , previous best loss:  0.35322943329811096  | saving best model ...
# | Epoch:  125 / 10000  | Loss:  0.3518  |
# Current loss:  0.35046496987342834  | , previous best loss:  0.3518472909927368  | saving best model ...
# | Epoch:  126 / 10000  | Loss:  0.3505  |
# Current loss:  0.3490813970565796  | , previous best loss:  0.35046496987342834  | saving best model ...
# | Epoch:  127 / 10000  | Loss:  0.3491  |
# Current loss:  0.34769633412361145  | , previous best loss:  0.3490813970565796  | saving best model ...
# | Epoch:  128 / 10000  | Loss:  0.3477  |
# Current loss:  0.3463103473186493  | , previous best loss:  0.34769633412361145  | saving best model ...
# | Epoch:  129 / 10000  | Loss:  0.3463  |
# Current loss:  0.3449232876300812  | , previous best loss:  0.3463103473186493  | saving best model ...
# | Epoch:  130 / 10000  | Loss:  0.3449  |
# Current loss:  0.34353530406951904  | , previous best loss:  0.3449232876300812  | saving best model ...
# | Epoch:  131 / 10000  | Loss:  0.3435  |
# Current loss:  0.34214675426483154  | , previous best loss:  0.34353530406951904  | saving best model ...
# | Epoch:  132 / 10000  | Loss:  0.3421  |
# Current loss:  0.3407568037509918  | , previous best loss:  0.34214675426483154  | saving best model ...
# | Epoch:  133 / 10000  | Loss:  0.3408  |
# Current loss:  0.3393654525279999  | , previous best loss:  0.3407568037509918  | saving best model ...
# | Epoch:  134 / 10000  | Loss:  0.3394  |
# Current loss:  0.33797335624694824  | , previous best loss:  0.3393654525279999  | saving best model ...
# | Epoch:  135 / 10000  | Loss:  0.338  |
# Current loss:  0.33658087253570557  | , previous best loss:  0.33797335624694824  | saving best model ...
# | Epoch:  136 / 10000  | Loss:  0.3366  |
# Current loss:  0.33518779277801514  | , previous best loss:  0.33658087253570557  | saving best model ...
# | Epoch:  137 / 10000  | Loss:  0.3352  |
# Current loss:  0.3337946832180023  | , previous best loss:  0.33518779277801514  | saving best model ...
# | Epoch:  138 / 10000  | Loss:  0.3338  |
# Current loss:  0.33240142464637756  | , previous best loss:  0.3337946832180023  | saving best model ...
# | Epoch:  139 / 10000  | Loss:  0.3324  |
# Current loss:  0.3310073912143707  | , previous best loss:  0.33240142464637756  | saving best model ...
# | Epoch:  140 / 10000  | Loss:  0.331  |
# Current loss:  0.3296130299568176  | , previous best loss:  0.3310073912143707  | saving best model ...
# | Epoch:  141 / 10000  | Loss:  0.3296  |
# Current loss:  0.3282189965248108  | , previous best loss:  0.3296130299568176  | saving best model ...
# | Epoch:  142 / 10000  | Loss:  0.3282  |
# Current loss:  0.3268248736858368  | , previous best loss:  0.3282189965248108  | saving best model ...
# | Epoch:  143 / 10000  | Loss:  0.3268  |
# Current loss:  0.32543087005615234  | , previous best loss:  0.3268248736858368  | saving best model ...
# | Epoch:  144 / 10000  | Loss:  0.3254  |
# Current loss:  0.32403624057769775  | , previous best loss:  0.32543087005615234  | saving best model ...
# | Epoch:  145 / 10000  | Loss:  0.324  |
# Current loss:  0.3226415514945984  | , previous best loss:  0.32403624057769775  | saving best model ...
# | Epoch:  146 / 10000  | Loss:  0.3226  |
# Current loss:  0.32124626636505127  | , previous best loss:  0.3226415514945984  | saving best model ...
# | Epoch:  147 / 10000  | Loss:  0.3212  |
# Current loss:  0.31984955072402954  | , previous best loss:  0.32124626636505127  | saving best model ...
# | Epoch:  148 / 10000  | Loss:  0.3198  |
# Current loss:  0.318452388048172  | , previous best loss:  0.31984955072402954  | saving best model ...
# | Epoch:  149 / 10000  | Loss:  0.3185  |
# Current loss:  0.317054808139801  | , previous best loss:  0.318452388048172  | saving best model ...
# | Epoch:  150 / 10000  | Loss:  0.3171  |
# Current loss:  0.31565621495246887  | , previous best loss:  0.317054808139801  | saving best model ...
# | Epoch:  151 / 10000  | Loss:  0.3157  |
# Current loss:  0.3142582178115845  | , previous best loss:  0.31565621495246887  | saving best model ...
# | Epoch:  152 / 10000  | Loss:  0.3143  |
# Current loss:  0.3128594160079956  | , previous best loss:  0.3142582178115845  | saving best model ...
# | Epoch:  153 / 10000  | Loss:  0.3129  |
# Current loss:  0.3114602565765381  | , previous best loss:  0.3128594160079956  | saving best model ...
# | Epoch:  154 / 10000  | Loss:  0.3115  |
# Current loss:  0.3100612759590149  | , previous best loss:  0.3114602565765381  | saving best model ...
# | Epoch:  155 / 10000  | Loss:  0.3101  |
# Current loss:  0.3086620271205902  | , previous best loss:  0.3100612759590149  | saving best model ...
# | Epoch:  156 / 10000  | Loss:  0.3087  |
# Current loss:  0.3072628378868103  | , previous best loss:  0.3086620271205902  | saving best model ...
# | Epoch:  157 / 10000  | Loss:  0.3073  |
# Current loss:  0.305863618850708  | , previous best loss:  0.3072628378868103  | saving best model ...
# | Epoch:  158 / 10000  | Loss:  0.3059  |
# Current loss:  0.3044646382331848  | , previous best loss:  0.305863618850708  | saving best model ...
# | Epoch:  159 / 10000  | Loss:  0.3045  |
# Current loss:  0.3030661940574646  | , previous best loss:  0.3044646382331848  | saving best model ...
# | Epoch:  160 / 10000  | Loss:  0.3031  |
# Current loss:  0.301668643951416  | , previous best loss:  0.3030661940574646  | saving best model ...
# | Epoch:  161 / 10000  | Loss:  0.3017  |
# Current loss:  0.3002718687057495  | , previous best loss:  0.301668643951416  | saving best model ...
# | Epoch:  162 / 10000  | Loss:  0.3003  |
# Current loss:  0.2688581049442291  | , previous best loss:  0.2701863944530487  | saving best model ...
# | Epoch:  185 / 10000  | Loss:  0.2689  |
# Current loss:  0.2675333619117737  | , previous best loss:  0.2688581049442291  | saving best model ...
# | Epoch:  186 / 10000  | Loss:  0.2675  |
# Current loss:  0.2662120759487152  | , previous best loss:  0.2675333619117737  | saving best model ...
# | Epoch:  187 / 10000  | Loss:  0.2662  |
# Current loss:  0.2648943066596985  | , previous best loss:  0.2662120759487152  | saving best model ...
# | Epoch:  188 / 10000  | Loss:  0.2649  |
# Current loss:  0.2635805010795593  | , previous best loss:  0.2648943066596985  | saving best model ...
# | Epoch:  189 / 10000  | Loss:  0.2636  |
# Current loss:  0.2622710168361664  | , previous best loss:  0.2635805010795593  | saving best model ...
# | Epoch:  190 / 10000  | Loss:  0.2623  |
# Current loss:  0.2609652578830719  | , previous best loss:  0.2622710168361664  | saving best model ...
# | Epoch:  191 / 10000  | Loss:  0.261  |
# Current loss:  0.2596636414527893  | , previous best loss:  0.2609652578830719  | saving best model ...
# | Epoch:  192 / 10000  | Loss:  0.2597  |
# Current loss:  0.2583662271499634  | , previous best loss:  0.2596636414527893  | saving best model ...
# | Epoch:  193 / 10000  | Loss:  0.2584  |
# Current loss:  0.25707322359085083  | , previous best loss:  0.2583662271499634  | saving best model ...
# | Epoch:  194 / 10000  | Loss:  0.2571  |
# Current loss:  0.25578421354293823  | , previous best loss:  0.25707322359085083  | saving best model ...
# | Epoch:  195 / 10000  | Loss:  0.2558  |
# Current loss:  0.2544991970062256  | , previous best loss:  0.25578421354293823  | saving best model ...
# | Epoch:  196 / 10000  | Loss:  0.2545  |
# Current loss:  0.25321826338768005  | , previous best loss:  0.2544991970062256  | saving best model ...
# | Epoch:  197 / 10000  | Loss:  0.2532  |
# Current loss:  0.2519413232803345  | , previous best loss:  0.25321826338768005  | saving best model ...
# | Epoch:  198 / 10000  | Loss:  0.2519  |
# Current loss:  0.25066807866096497  | , previous best loss:  0.2519413232803345  | saving best model ...
# | Epoch:  199 / 10000  | Loss:  0.2507  |
# Current loss:  0.24939872324466705  | , previous best loss:  0.25066807866096497  | saving best model ...
# | Epoch:  200 / 10000  | Loss:  0.2494  |
# Current loss:  0.24813345074653625  | , previous best loss:  0.24939872324466705  | saving best model ...
# | Epoch:  201 / 10000  | Loss:  0.2481  |
# Current loss:  0.24687200784683228  | , previous best loss:  0.24813345074653625  | saving best model ...
# | Epoch:  202 / 10000  | Loss:  0.2469  |
# Current loss:  0.24561426043510437  | , previous best loss:  0.24687200784683228  | saving best model ...
# | Epoch:  203 / 10000  | Loss:  0.2456  |
# Current loss:  0.24436011910438538  | , previous best loss:  0.24561426043510437  | saving best model ...
# | Epoch:  204 / 10000  | Loss:  0.2444  |
# Current loss:  0.24311013519763947  | , previous best loss:  0.24436011910438538  | saving best model ...
# | Epoch:  205 / 10000  | Loss:  0.2431  |
# Current loss:  0.2418639063835144  | , previous best loss:  0.24311013519763947  | saving best model ...
# | Epoch:  206 / 10000  | Loss:  0.2419  |
# Current loss:  0.2406214475631714  | , previous best loss:  0.2418639063835144  | saving best model ...
# | Epoch:  207 / 10000  | Loss:  0.2406  |
# Current loss:  0.23938295245170593  | , previous best loss:  0.2406214475631714  | saving best model ...
# | Epoch:  208 / 10000  | Loss:  0.2394  |
# Current loss:  0.23814816772937775  | , previous best loss:  0.23938295245170593  | saving best model ...
# | Epoch:  209 / 10000  | Loss:  0.2381  |
# Current loss:  0.23691700398921967  | , previous best loss:  0.23814816772937775  | saving best model ...
# | Epoch:  210 / 10000  | Loss:  0.2369  |
# Current loss:  0.23568935692310333  | , previous best loss:  0.23691700398921967  | saving best model ...
# | Epoch:  211 / 10000  | Loss:  0.2357  |
# Current loss:  0.23446537554264069  | , previous best loss:  0.23568935692310333  | saving best model ...
# | Epoch:  212 / 10000  | Loss:  0.2345  |
# Current loss:  0.23324504494667053  | , previous best loss:  0.23446537554264069  | saving best model ...
# | Epoch:  213 / 10000  | Loss:  0.2332  |
# Current loss:  0.23202882707118988  | , previous best loss:  0.23324504494667053  | saving best model ...
# | Epoch:  214 / 10000  | Loss:  0.232  |
# Current loss:  0.2308162897825241  | , previous best loss:  0.23202882707118988  | saving best model ...
# | Epoch:  215 / 10000  | Loss:  0.2308  |
# Current loss:  0.22960762679576874  | , previous best loss:  0.2308162897825241  | saving best model ...
# | Epoch:  216 / 10000  | Loss:  0.2296  |
# Current loss:  0.22840294241905212  | , previous best loss:  0.22960762679576874  | saving best model ...
# | Epoch:  217 / 10000  | Loss:  0.2284  |
# Current loss:  0.22720208764076233  | , previous best loss:  0.22840294241905212  | saving best model ...
# | Epoch:  218 / 10000  | Loss:  0.2272  |
# Current loss:  0.22600515186786652  | , previous best loss:  0.22720208764076233  | saving best model ...
# | Epoch:  219 / 10000  | Loss:  0.226  |
# Current loss:  0.2248121201992035  | , previous best loss:  0.22600515186786652  | saving best model ...
# | Epoch:  220 / 10000  | Loss:  0.2248  |
# Current loss:  0.22362323105335236  | , previous best loss:  0.2248121201992035  | saving best model ...
# | Epoch:  221 / 10000  | Loss:  0.2236  |
# Current loss:  0.22243860363960266  | , previous best loss:  0.22362323105335236  | saving best model ...
# | Epoch:  222 / 10000  | Loss:  0.2224  |
# Current loss:  0.22125795483589172  | , previous best loss:  0.22243860363960266  | saving best model ...
# | Epoch:  223 / 10000  | Loss:  0.2213  |
# Current loss:  0.2200811356306076  | , previous best loss:  0.22125795483589172  | saving best model ...
# | Epoch:  224 / 10000  | Loss:  0.2201  |
# Current loss:  0.21890832483768463  | , previous best loss:  0.2200811356306076  | saving best model ...
# | Epoch:  225 / 10000  | Loss:  0.2189  |
# Current loss:  0.21773956716060638  | , previous best loss:  0.21890832483768463  | saving best model ...
# | Epoch:  226 / 10000  | Loss:  0.2177  |
# Current loss:  0.2165749967098236  | , previous best loss:  0.21773956716060638  | saving best model ...
# | Epoch:  227 / 10000  | Loss:  0.2166  |
# Current loss:  0.21541424095630646  | , previous best loss:  0.2165749967098236  | saving best model ...
# | Epoch:  228 / 10000  | Loss:  0.2154  |
# Current loss:  0.1898324340581894  | , previous best loss:  0.19090010225772858  | saving best model ...
# | Epoch:  251 / 10000  | Loss:  0.1898  |
# Current loss:  0.18876874446868896  | , previous best loss:  0.1898324340581894  | saving best model ...
# | Epoch:  252 / 10000  | Loss:  0.1888  |
# Current loss:  0.18770907819271088  | , previous best loss:  0.18876874446868896  | saving best model ...
# | Epoch:  253 / 10000  | Loss:  0.1877  |
# Current loss:  0.18665353953838348  | , previous best loss:  0.18770907819271088  | saving best model ...
# | Epoch:  254 / 10000  | Loss:  0.1867  |
# Current loss:  0.1856021136045456  | , previous best loss:  0.18665353953838348  | saving best model ...
# | Epoch:  255 / 10000  | Loss:  0.1856  |
# Current loss:  0.18455490469932556  | , previous best loss:  0.1856021136045456  | saving best model ...
# | Epoch:  256 / 10000  | Loss:  0.1846  |
# Current loss:  0.18351192772388458  | , previous best loss:  0.18455490469932556  | saving best model ...
# | Epoch:  257 / 10000  | Loss:  0.1835  |
# Current loss:  0.1824733167886734  | , previous best loss:  0.18351192772388458  | saving best model ...
# | Epoch:  258 / 10000  | Loss:  0.1825  |
# Current loss:  0.18143874406814575  | , previous best loss:  0.1824733167886734  | saving best model ...
# | Epoch:  259 / 10000  | Loss:  0.1814  |
# Current loss:  0.1804082691669464  | , previous best loss:  0.18143874406814575  | saving best model ...
# | Epoch:  260 / 10000  | Loss:  0.1804  |
# Current loss:  0.17938198149204254  | , previous best loss:  0.1804082691669464  | saving best model ...
# | Epoch:  261 / 10000  | Loss:  0.1794  |
# Current loss:  0.17835979163646698  | , previous best loss:  0.17938198149204254  | saving best model ...
# | Epoch:  262 / 10000  | Loss:  0.1784  |
# Current loss:  0.17734171450138092  | , previous best loss:  0.17835979163646698  | saving best model ...
# | Epoch:  263 / 10000  | Loss:  0.1773  |
# Current loss:  0.17632777988910675  | , previous best loss:  0.17734171450138092  | saving best model ...
# | Epoch:  264 / 10000  | Loss:  0.1763  |
# Current loss:  0.17531803250312805  | , previous best loss:  0.17632777988910675  | saving best model ...
# | Epoch:  265 / 10000  | Loss:  0.1753  |
# Current loss:  0.1743125021457672  | , previous best loss:  0.17531803250312805  | saving best model ...
# | Epoch:  266 / 10000  | Loss:  0.1743  |
# Current loss:  0.17331111431121826  | , previous best loss:  0.1743125021457672  | saving best model ...
# | Epoch:  267 / 10000  | Loss:  0.1733  |
# Current loss:  0.1723138689994812  | , previous best loss:  0.17331111431121826  | saving best model ...
# | Epoch:  268 / 10000  | Loss:  0.1723  |
# Current loss:  0.17132078111171722  | , previous best loss:  0.1723138689994812  | saving best model ...
# | Epoch:  269 / 10000  | Loss:  0.1713  |
# Current loss:  0.17033183574676514  | , previous best loss:  0.17132078111171722  | saving best model ...
# | Epoch:  270 / 10000  | Loss:  0.1703  |
# Current loss:  0.16934698820114136  | , previous best loss:  0.17033183574676514  | saving best model ...
# | Epoch:  271 / 10000  | Loss:  0.1693  |
# Current loss:  0.1683662235736847  | , previous best loss:  0.16934698820114136  | saving best model ...
# | Epoch:  272 / 10000  | Loss:  0.1684  |
# Current loss:  0.1673896759748459  | , previous best loss:  0.1683662235736847  | saving best model ...
# | Epoch:  273 / 10000  | Loss:  0.1674  |
# Current loss:  0.16641725599765778  | , previous best loss:  0.1673896759748459  | saving best model ...
# | Epoch:  274 / 10000  | Loss:  0.1664  |
# Current loss:  0.16544902324676514  | , previous best loss:  0.16641725599765778  | saving best model ...
# | Epoch:  275 / 10000  | Loss:  0.1654  |
# Current loss:  0.1644849330186844  | , previous best loss:  0.16544902324676514  | saving best model ...
# | Epoch:  276 / 10000  | Loss:  0.1645  |
# Current loss:  0.1635250598192215  | , previous best loss:  0.1644849330186844  | saving best model ...
# | Epoch:  277 / 10000  | Loss:  0.1635  |
# Current loss:  0.1625693440437317  | , previous best loss:  0.1635250598192215  | saving best model ...
# | Epoch:  278 / 10000  | Loss:  0.1626  |
# Current loss:  0.16161775588989258  | , previous best loss:  0.1625693440437317  | saving best model ...
# | Epoch:  279 / 10000  | Loss:  0.1616  |
# Current loss:  0.16067029535770416  | , previous best loss:  0.16161775588989258  | saving best model ...
# | Epoch:  280 / 10000  | Loss:  0.1607  |
# Current loss:  0.15972700715065002  | , previous best loss:  0.16067029535770416  | saving best model ...
# | Epoch:  281 / 10000  | Loss:  0.1597  |
# Current loss:  0.15878795087337494  | , previous best loss:  0.15972700715065002  | saving best model ...
# | Epoch:  282 / 10000  | Loss:  0.1588  |
# Current loss:  0.15785300731658936  | , previous best loss:  0.15878795087337494  | saving best model ...
# | Epoch:  283 / 10000  | Loss:  0.1579  |
# Current loss:  0.15692217648029327  | , previous best loss:  0.15785300731658936  | saving best model ...
# | Epoch:  284 / 10000  | Loss:  0.1569  |
# Current loss:  0.15599560737609863  | , previous best loss:  0.15692217648029327  | saving best model ...
# | Epoch:  285 / 10000  | Loss:  0.156  |
# Current loss:  0.1550731211900711  | , previous best loss:  0.15599560737609863  | saving best model ...
# | Epoch:  286 / 10000  | Loss:  0.1551  |
# Current loss:  0.1541547179222107  | , previous best loss:  0.1550731211900711  | saving best model ...
# | Epoch:  287 / 10000  | Loss:  0.1542  |
# Current loss:  0.15324044227600098  | , previous best loss:  0.1541547179222107  | saving best model ...
# | Epoch:  288 / 10000  | Loss:  0.1532  |
# Current loss:  0.15233023464679718  | , previous best loss:  0.15324044227600098  | saving best model ...
# | Epoch:  289 / 10000  | Loss:  0.1523  |
# Current loss:  0.15142415463924408  | , previous best loss:  0.15233023464679718  | saving best model ...
# | Epoch:  290 / 10000  | Loss:  0.1514  |
# Current loss:  0.15052232146263123  | , previous best loss:  0.15142415463924408  | saving best model ...
# | Epoch:  291 / 10000  | Loss:  0.1505  |
# Current loss:  0.1496247500181198  | , previous best loss:  0.15052232146263123  | saving best model ...
# | Epoch:  292 / 10000  | Loss:  0.1496  |
# Current loss:  0.148731529712677  | , previous best loss:  0.1496247500181198  | saving best model ...
# | Epoch:  293 / 10000  | Loss:  0.1487  |
# Current loss:  0.14784260094165802  | , previous best loss:  0.148731529712677  | saving best model ...
# | Epoch:  294 / 10000  | Loss:  0.1478  |
# Current loss:  0.1469578742980957  | , previous best loss:  0.14784260094165802  | saving best model ...
# | Epoch:  295 / 10000  | Loss:  0.147  |
# Current loss:  0.14607729017734528  | , previous best loss:  0.1469578742980957  | saving best model ...
# | Epoch:  296 / 10000  | Loss:  0.1461  |
# Current loss:  0.14520099759101868  | , previous best loss:  0.14607729017734528  | saving best model ...
# | Epoch:  297 / 10000  | Loss:  0.1452  |
# Current loss:  0.14432887732982635  | , previous best loss:  0.14520099759101868  | saving best model ...
# | Epoch:  298 / 10000  | Loss:  0.1443  |
# Current loss:  0.14346100389957428  | , previous best loss:  0.14432887732982635  | saving best model ...
# | Epoch:  299 / 10000  | Loss:  0.1435  |
# Current loss:  0.14259733259677887  | , previous best loss:  0.14346100389957428  | saving best model ...
# | Epoch:  300 / 10000  | Loss:  0.1426  |
# Current loss:  0.14173786342144012  | , previous best loss:  0.14259733259677887  | saving best model ...
# | Epoch:  301 / 10000  | Loss:  0.1417  |
# Current loss:  0.14088261127471924  | , previous best loss:  0.14173786342144012  | saving best model ...
# | Epoch:  302 / 10000  | Loss:  0.1409  |
# Current loss:  0.1400316208600998  | , previous best loss:  0.14088261127471924  | saving best model ...
# | Epoch:  303 / 10000  | Loss:  0.14  |
# Current loss:  0.13918490707874298  | , previous best loss:  0.1400316208600998  | saving best model ...
# | Epoch:  304 / 10000  | Loss:  0.1392  |
# Current loss:  0.13834239542484283  | , previous best loss:  0.13918490707874298  | saving best model ...
# | Epoch:  305 / 10000  | Loss:  0.1383  |
# Current loss:  0.13750405609607697  | , previous best loss:  0.13834239542484283  | saving best model ...
# | Epoch:  306 / 10000  | Loss:  0.1375  |
# Current loss:  0.13666997849941254  | , previous best loss:  0.13750405609607697  | saving best model ...
# | Epoch:  307 / 10000  | Loss:  0.1367  |
# Current loss:  0.13584014773368835  | , previous best loss:  0.13666997849941254  | saving best model ...
# | Epoch:  308 / 10000  | Loss:  0.1358  |
# Current loss:  0.13501456379890442  | , previous best loss:  0.13584014773368835  | saving best model ...
# | Epoch:  309 / 10000  | Loss:  0.135  |
# Current loss:  0.1341932713985443  | , previous best loss:  0.13501456379890442  | saving best model ...
# | Epoch:  310 / 10000  | Loss:  0.1342  |
# Current loss:  0.13337625563144684  | , previous best loss:  0.1341932713985443  | saving best model ...
# | Epoch:  311 / 10000  | Loss:  0.1334  |
# Current loss:  0.1325635313987732  | , previous best loss:  0.13337625563144684  | saving best model ...
# | Epoch:  312 / 10000  | Loss:  0.1326  |
# Current loss:  0.13175511360168457  | , previous best loss:  0.1325635313987732  | saving best model ...
# | Epoch:  313 / 10000  | Loss:  0.1318  |
# Current loss:  0.13095097243785858  | , previous best loss:  0.13175511360168457  | saving best model ...
# | Epoch:  314 / 10000  | Loss:  0.131  |
# Current loss:  0.13015106320381165  | , previous best loss:  0.13095097243785858  | saving best model ...
# | Epoch:  315 / 10000  | Loss:  0.1302  |
# Current loss:  0.12935544550418854  | , previous best loss:  0.13015106320381165  | saving best model ...
# | Epoch:  316 / 10000  | Loss:  0.1294  |
# Current loss:  0.0032099904492497444  | , previous best loss:  0.003224266692996025  | saving best model ...
# | Epoch:  1303 / 10000  | Loss:  0.0032  |
# Current loss:  0.003195761702954769  | , previous best loss:  0.0032099904492497444  | saving best model ...
# | Epoch:  1304 / 10000  | Loss:  0.0032  |
# Current loss:  0.003181581851094961  | , previous best loss:  0.003195761702954769  | saving best model ...
# | Epoch:  1305 / 10000  | Loss:  0.0032  |
# Current loss:  0.0031674522906541824  | , previous best loss:  0.003181581851094961  | saving best model ...
# | Epoch:  1306 / 10000  | Loss:  0.0032  |
# Current loss:  0.003153374418616295  | , previous best loss:  0.0031674522906541824  | saving best model ...
# | Epoch:  1307 / 10000  | Loss:  0.0032  |
# Current loss:  0.0031393440440297127  | , previous best loss:  0.003153374418616295  | saving best model ...
# | Epoch:  1308 / 10000  | Loss:  0.0031  |
# Current loss:  0.003125369781628251  | , previous best loss:  0.0031393440440297127  | saving best model ...
# | Epoch:  1309 / 10000  | Loss:  0.0031  |
# Current loss:  0.003111443016678095  | , previous best loss:  0.003125369781628251  | saving best model ...
# | Epoch:  1310 / 10000  | Loss:  0.0031  |
# Current loss:  0.003097567008808255  | , previous best loss:  0.003111443016678095  | saving best model ...
# | Epoch:  1311 / 10000  | Loss:  0.0031  |
# Current loss:  0.00308373779989779  | , previous best loss:  0.003097567008808255  | saving best model ...
# | Epoch:  1312 / 10000  | Loss:  0.0031  |
# Current loss:  0.003069960977882147  | , previous best loss:  0.00308373779989779  | saving best model ...
# | Epoch:  1313 / 10000  | Loss:  0.0031  |
# Current loss:  0.003056230489164591  | , previous best loss:  0.003069960977882147  | saving best model ...
# | Epoch:  1314 / 10000  | Loss:  0.0031  |
# Current loss:  0.0030425507575273514  | , previous best loss:  0.003056230489164591  | saving best model ...
# | Epoch:  1315 / 10000  | Loss:  0.003  |
# Current loss:  0.0030289189890027046  | , previous best loss:  0.0030425507575273514  | saving best model ...
# | Epoch:  1316 / 10000  | Loss:  0.003  |
# Current loss:  0.0030153386760503054  | , previous best loss:  0.0030289189890027046  | saving best model ...
# | Epoch:  1317 / 10000  | Loss:  0.003  |
# Current loss:  0.0030018037650734186  | , previous best loss:  0.0030153386760503054  | saving best model ...
# | Epoch:  1318 / 10000  | Loss:  0.003  |
# Current loss:  0.0029883175157010555  | , previous best loss:  0.0030018037650734186  | saving best model ...
# | Epoch:  1319 / 10000  | Loss:  0.003  |
# Current loss:  0.002974884817376733  | , previous best loss:  0.0029883175157010555  | saving best model ...
# | Epoch:  1320 / 10000  | Loss:  0.003  |
# Current loss:  0.002961500780656934  | , previous best loss:  0.002974884817376733  | saving best model ...
# | Epoch:  1321 / 10000  | Loss:  0.003  |
# Current loss:  0.0029481658712029457  | , previous best loss:  0.002961500780656934  | saving best model ...
# | Epoch:  1322 / 10000  | Loss:  0.0029  |
# Current loss:  0.0029348833486437798  | , previous best loss:  0.0029481658712029457  | saving best model ...
# | Epoch:  1323 / 10000  | Loss:  0.0029  |
# Current loss:  0.002921648323535919  | , previous best loss:  0.0029348833486437798  | saving best model ...
# | Epoch:  1324 / 10000  | Loss:  0.0029  |
# Current loss:  0.0029084619600325823  | , previous best loss:  0.002921648323535919  | saving best model ...
# | Epoch:  1325 / 10000  | Loss:  0.0029  |
# Current loss:  0.0028953254222869873  | , previous best loss:  0.0029084619600325823  | saving best model ...
# | Epoch:  1326 / 10000  | Loss:  0.0029  |
# Current loss:  0.002882237546145916  | , previous best loss:  0.0028953254222869873  | saving best model ...
# | Epoch:  1327 / 10000  | Loss:  0.0029  |
# Current loss:  0.0028691990301012993  | , previous best loss:  0.002882237546145916  | saving best model ...
# | Epoch:  1328 / 10000  | Loss:  0.0029  |
# Current loss:  0.002856209874153137  | , previous best loss:  0.0028691990301012993  | saving best model ...
# | Epoch:  1329 / 10000  | Loss:  0.0029  |
# Current loss:  0.002843269146978855  | , previous best loss:  0.002856209874153137  | saving best model ...
# | Epoch:  1330 / 10000  | Loss:  0.0028  |
# Current loss:  0.002830376848578453  | , previous best loss:  0.002843269146978855  | saving best model ...
# | Epoch:  1331 / 10000  | Loss:  0.0028  |
# Current loss:  0.002817532978951931  | , previous best loss:  0.002830376848578453  | saving best model ...
# | Epoch:  1332 / 10000  | Loss:  0.0028  |
# Current loss:  0.00280473823659122  | , previous best loss:  0.002817532978951931  | saving best model ...
# | Epoch:  1333 / 10000  | Loss:  0.0028  |
# Current loss:  0.002791991923004389  | , previous best loss:  0.00280473823659122  | saving best model ...
# | Epoch:  1334 / 10000  | Loss:  0.0028  |
# Current loss:  0.0027792893815785646  | , previous best loss:  0.002791991923004389  | saving best model ...
# | Epoch:  1335 / 10000  | Loss:  0.0028  |
# Current loss:  0.002766637597233057  | , previous best loss:  0.0027792893815785646  | saving best model ...
# | Epoch:  1336 / 10000  | Loss:  0.0028  |
# Current loss:  0.002754031214863062  | , previous best loss:  0.002766637597233057  | saving best model ...
# | Epoch:  1337 / 10000  | Loss:  0.0028  |
# Current loss:  0.002741473726928234  | , previous best loss:  0.002754031214863062  | saving best model ...
# | Epoch:  1338 / 10000  | Loss:  0.0027  |
# Current loss:  0.0027289658319205046  | , previous best loss:  0.002741473726928234  | saving best model ...
# | Epoch:  1339 / 10000  | Loss:  0.0027  |
# Current loss:  0.002716509625315666  | , previous best loss:  0.0027289658319205046  | saving best model ...
# | Epoch:  1340 / 10000  | Loss:  0.0027  |
# Current loss:  0.002704096958041191  | , previous best loss:  0.002716509625315666  | saving best model ...
# | Epoch:  1341 / 10000  | Loss:  0.0027  |
# Current loss:  0.0026917364448308945  | , previous best loss:  0.002704096958041191  | saving best model ...
# | Epoch:  1342 / 10000  | Loss:  0.0027  |
# Current loss:  0.0026794197037816048  | , previous best loss:  0.0026917364448308945  | saving best model ...
# | Epoch:  1343 / 10000  | Loss:  0.0027  |
# Current loss:  0.002667152788490057  | , previous best loss:  0.0026794197037816048  | saving best model ...
# | Epoch:  1344 / 10000  | Loss:  0.0027  |
# Current loss:  0.002654931740835309  | , previous best loss:  0.002667152788490057  | saving best model ...
# | Epoch:  1345 / 10000  | Loss:  0.0027  |
# Current loss:  0.0026427574921399355  | , previous best loss:  0.002654931740835309  | saving best model ...
# | Epoch:  1346 / 10000  | Loss:  0.0026  |
# Current loss:  0.002630634233355522  | , previous best loss:  0.0026427574921399355  | saving best model ...
# | Epoch:  1347 / 10000  | Loss:  0.0026  |
# Current loss:  0.002618554048240185  | , previous best loss:  0.002630634233355522  | saving best model ...
# | Epoch:  1348 / 10000  | Loss:  0.0026  |
# Current loss:  0.0026065208949148655  | , previous best loss:  0.002618554048240185  | saving best model ...
# | Epoch:  1349 / 10000  | Loss:  0.0026  |
# Current loss:  0.0025945340748876333  | , previous best loss:  0.0026065208949148655  | saving best model ...
# | Epoch:  1350 / 10000  | Loss:  0.0026  |
# Current loss:  0.0025825954508036375  | , previous best loss:  0.0025945340748876333  | saving best model ...
# | Epoch:  1351 / 10000  | Loss:  0.0026  |
# Current loss:  0.0025707026943564415  | , previous best loss:  0.0025825954508036375  | saving best model ...
# | Epoch:  1352 / 10000  | Loss:  0.0026  |
# Current loss:  0.002558857901021838  | , previous best loss:  0.0025707026943564415  | saving best model ...
# | Epoch:  1353 / 10000  | Loss:  0.0026  |
# Current loss:  0.0025470599066466093  | , previous best loss:  0.002558857901021838  | saving best model ...
# | Epoch:  1354 / 10000  | Loss:  0.0025  |
# Current loss:  0.002535308711230755  | , previous best loss:  0.0025470599066466093  | saving best model ...
# | Epoch:  1355 / 10000  | Loss:  0.0025  |
# Current loss:  0.0025236031506210566  | , previous best loss:  0.002535308711230755  | saving best model ...
# | Epoch:  1356 / 10000  | Loss:  0.0025  |
# Current loss:  0.0025119418278336525  | , previous best loss:  0.0025236031506210566  | saving best model ...
# | Epoch:  1357 / 10000  | Loss:  0.0025  |
# Current loss:  0.00250032776966691  | , previous best loss:  0.0025119418278336525  | saving best model ...
# | Epoch:  1358 / 10000  | Loss:  0.0025  |
# Current loss:  0.002488758647814393  | , previous best loss:  0.00250032776966691  | saving best model ...
# | Epoch:  1359 / 10000  | Loss:  0.0025  |
# Current loss:  0.0024772353935986757  | , previous best loss:  0.002488758647814393  | saving best model ...
# | Epoch:  1360 / 10000  | Loss:  0.0025  |
# Current loss:  0.0024657524190843105  | , previous best loss:  0.0024772353935986757  | saving best model ...
# | Epoch:  1361 / 10000  | Loss:  0.0025  |
# Current loss:  0.0024543150793761015  | , previous best loss:  0.0024657524190843105  | saving best model ...
# | Epoch:  1362 / 10000  | Loss:  0.0025  |
# Current loss:  0.0024429205805063248  | , previous best loss:  0.0024543150793761015  | saving best model ...
# | Epoch:  1363 / 10000  | Loss:  0.0024  |
# Current loss:  0.0024315682239830494  | , previous best loss:  0.0024429205805063248  | saving best model ...
# | Epoch:  1364 / 10000  | Loss:  0.0024  |
# Current loss:  0.002420263597741723  | , previous best loss:  0.0024315682239830494  | saving best model ...
# | Epoch:  1365 / 10000  | Loss:  0.0024  |
# Current loss:  0.002409006468951702  | , previous best loss:  0.002420263597741723  | saving best model ...
# | Epoch:  1366 / 10000  | Loss:  0.0024  |
# | Epoch:  1388 / 10000  | Loss:  0.0022  |
# Current loss:  0.0021621340420097113  | , previous best loss:  0.002172392327338457  | saving best model ...
# | Epoch:  1389 / 10000  | Loss:  0.0022  |
# Current loss:  0.002151917666196823  | , previous best loss:  0.0021621340420097113  | saving best model ...
# | Epoch:  1390 / 10000  | Loss:  0.0022  |
# Current loss:  0.0021417406387627125  | , previous best loss:  0.002151917666196823  | saving best model ...
# | Epoch:  1391 / 10000  | Loss:  0.0021  |
# Current loss:  0.002131607150658965  | , previous best loss:  0.0021417406387627125  | saving best model ...
# | Epoch:  1392 / 10000  | Loss:  0.0021  |
# Current loss:  0.0021215120796114206  | , previous best loss:  0.002131607150658965  | saving best model ...
# | Epoch:  1393 / 10000  | Loss:  0.0021  |
# Current loss:  0.0021114624105393887  | , previous best loss:  0.0021215120796114206  | saving best model ...
# | Epoch:  1394 / 10000  | Loss:  0.0021  |
# Current loss:  0.0021014544181525707  | , previous best loss:  0.0021114624105393887  | saving best model ...
# | Epoch:  1395 / 10000  | Loss:  0.0021  |
# | Epoch:  1396 / 10000  | Loss:  0.0021  |
# | Epoch:  1397 / 10000  | Loss:  0.0021  |
# | Epoch:  1398 / 10000  | Loss:  0.0021  |
# | Epoch:  1399 / 10000  | Loss:  0.0021  |
# | Epoch:  1400 / 10000  | Loss:  0.0021  |
# | Epoch:  1401 / 10000  | Loss:  0.002  |
# | Epoch:  1402 / 10000  | Loss:  0.002  |
# | Epoch:  1403 / 10000  | Loss:  0.002  |
# Convergence!

# %%
with torch.no_grad():
    print(criterion(y_test, ML(X_test).detach()))
# Out:
# tensor(0.0019)

# %%
MPS = MPSv3(input_dim = Fin, degree = dg, num_knots = nk, num_neurons = nm, output_dim = Fout, bias = True).to(device)
learning_r = 1e-2
criterion = torch.nn.MSELoss(reduction='mean')
optimizer = torch.optim.Adam(MPS.parameters(), lr=learning_r)

Iteration = 10000
ploss_list = []
bloss = 9999

tpat = 0
patientc = 20
patientr = 5
lr_tor = 1e-7
n = X_train.size()[0]

for t in range(Iteration):
    # Forward pass: Compute predicted y by passing x to the modelsp
    pyb_af = MPS(X_train)
    
    # Extracted the feature from model
    WB1 = MPS.sp1.control_p; DB1 = diag_mat_weights(WB1.size()[0]).to(device)
    
    # Calculate the MSELoss & penalty
    loss = criterion(y_train, pyb_af) 
    penalty = LambdaB * torch.norm(DB1 @ WB1)*(1/nm) 
    #penalty = 4.9 * torch.norm(DB1 @ WB1)*(1/n) 
    #+ (Lambdadict['L']/n) * torch.norm(DL @ WL.T)
    loss += penalty
    
    ploss_list.append(loss.item())
    

    if (t > 0) and ((ploss_list[t-1]-ploss_list[t])<tor):        
        if  (tpat % patientr) == 0 :
            learning_r *= 0.2 
            tpat += 1
            print('Learning rate reduce to ', learning_r)
            optimizer = torch.optim.Adam(MPS.parameters(), lr=learning_r)
            if learning_r <= lr_tor:
                print('Convergence!')
                break
        elif tpat < patientc:
            tpat += 1
            pass
        else:
            print('Convergence!')
            break
    else:
        if loss < bloss:
            print('Current loss: ', loss.item(), ' | , previous best loss: ', bloss, ' | saving best model ...')
            torch.save(MPS.state_dict(), './1BestMPSn'+str(X_train.size()[0])+'h'+str(nm)+'k'+str(nk))
            bloss = loss.item()
            tpat = 0
        tpat += 1
        
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()
    print('| Epoch: ',t+1,'/',str(Iteration),' | Loss: ', np.round(loss.item(), 4),' |')
# Out:
# Current loss:  0.7689186334609985  | , previous best loss:  9999  | saving best model ...
# | Epoch:  1 / 10000  | Loss:  0.7689  |
# | Epoch:  2 / 10000  | Loss:  0.8576  |
# Current loss:  0.7505857944488525  | , previous best loss:  0.7689186334609985  | saving best model ...
# | Epoch:  3 / 10000  | Loss:  0.7506  |
# Current loss:  0.73035728931427  | , previous best loss:  0.7505857944488525  | saving best model ...
# | Epoch:  4 / 10000  | Loss:  0.7304  |
# | Epoch:  5 / 10000  | Loss:  0.7699  |
# | Epoch:  6 / 10000  | Loss:  0.7433  |
# Current loss:  0.7008974552154541  | , previous best loss:  0.73035728931427  | saving best model ...
# | Epoch:  7 / 10000  | Loss:  0.7009  |
# Current loss:  0.6980769634246826  | , previous best loss:  0.7008974552154541  | saving best model ...
# | Epoch:  8 / 10000  | Loss:  0.6981  |
# | Epoch:  9 / 10000  | Loss:  0.7145  |
# | Epoch:  10 / 10000  | Loss:  0.7072  |
# Current loss:  0.6810963153839111  | , previous best loss:  0.6980769634246826  | saving best model ...
# | Epoch:  11 / 10000  | Loss:  0.6811  |
# Current loss:  0.6654301285743713  | , previous best loss:  0.6810963153839111  | saving best model ...
# | Epoch:  12 / 10000  | Loss:  0.6654  |
# | Epoch:  13 / 10000  | Loss:  0.6693  |
# | Epoch:  14 / 10000  | Loss:  0.6732  |
# Current loss:  0.6619330644607544  | , previous best loss:  0.6654301285743713  | saving best model ...
# | Epoch:  15 / 10000  | Loss:  0.6619  |
# Current loss:  0.6448630690574646  | , previous best loss:  0.6619330644607544  | saving best model ...
# | Epoch:  16 / 10000  | Loss:  0.6449  |
# Current loss:  0.637484073638916  | , previous best loss:  0.6448630690574646  | saving best model ...
# | Epoch:  17 / 10000  | Loss:  0.6375  |
# | Epoch:  18 / 10000  | Loss:  0.6397  |
# | Epoch:  19 / 10000  | Loss:  0.6386  |
# Current loss:  0.6285727024078369  | , previous best loss:  0.637484073638916  | saving best model ...
# | Epoch:  20 / 10000  | Loss:  0.6286  |
# Current loss:  0.6175536513328552  | , previous best loss:  0.6285727024078369  | saving best model ...
# | Epoch:  21 / 10000  | Loss:  0.6176  |
# Current loss:  0.6137416362762451  | , previous best loss:  0.6175536513328552  | saving best model ...
# | Epoch:  22 / 10000  | Loss:  0.6137  |
# | Epoch:  23 / 10000  | Loss:  0.6143  |
# Current loss:  0.6108994483947754  | , previous best loss:  0.6137416362762451  | saving best model ...
# | Epoch:  24 / 10000  | Loss:  0.6109  |
# Current loss:  0.6025102138519287  | , previous best loss:  0.6108994483947754  | saving best model ...
# | Epoch:  25 / 10000  | Loss:  0.6025  |
# Current loss:  0.595737874507904  | , previous best loss:  0.6025102138519287  | saving best model ...
# | Epoch:  26 / 10000  | Loss:  0.5957  |
# Current loss:  0.5939549207687378  | , previous best loss:  0.595737874507904  | saving best model ...
# | Epoch:  27 / 10000  | Loss:  0.594  |
# Current loss:  0.5928718447685242  | , previous best loss:  0.5939549207687378  | saving best model ...
# | Epoch:  28 / 10000  | Loss:  0.5929  |
# Current loss:  0.5880378484725952  | , previous best loss:  0.5928718447685242  | saving best model ...
# | Epoch:  29 / 10000  | Loss:  0.588  |
# Current loss:  0.5815088152885437  | , previous best loss:  0.5880378484725952  | saving best model ...
# | Epoch:  30 / 10000  | Loss:  0.5815  |
# Current loss:  0.5777388215065002  | , previous best loss:  0.5815088152885437  | saving best model ...
# | Epoch:  31 / 10000  | Loss:  0.5777  |
# Current loss:  0.5764300227165222  | , previous best loss:  0.5777388215065002  | saving best model ...
# | Epoch:  32 / 10000  | Loss:  0.5764  |
# Current loss:  0.5736167430877686  | , previous best loss:  0.5764300227165222  | saving best model ...
# | Epoch:  33 / 10000  | Loss:  0.5736  |
# Current loss:  0.5684781074523926  | , previous best loss:  0.5736167430877686  | saving best model ...
# | Epoch:  34 / 10000  | Loss:  0.5685  |
# Current loss:  0.5641640424728394  | , previous best loss:  0.5684781074523926  | saving best model ...
# | Epoch:  35 / 10000  | Loss:  0.5642  |
# Current loss:  0.5621095895767212  | , previous best loss:  0.5641640424728394  | saving best model ...
# | Epoch:  36 / 10000  | Loss:  0.5621  |
# Current loss:  0.5599405765533447  | , previous best loss:  0.5621095895767212  | saving best model ...
# | Epoch:  37 / 10000  | Loss:  0.5599  |
# Current loss:  0.5559383034706116  | , previous best loss:  0.5599405765533447  | saving best model ...
# | Epoch:  38 / 10000  | Loss:  0.5559  |
# Current loss:  0.5517870187759399  | , previous best loss:  0.5559383034706116  | saving best model ...
# | Epoch:  39 / 10000  | Loss:  0.5518  |
# Current loss:  0.549229621887207  | , previous best loss:  0.5517870187759399  | saving best model ...
# | Epoch:  40 / 10000  | Loss:  0.5492  |
# Current loss:  0.547078013420105  | , previous best loss:  0.549229621887207  | saving best model ...
# | Epoch:  41 / 10000  | Loss:  0.5471  |
# Current loss:  0.5436854958534241  | , previous best loss:  0.547078013420105  | saving best model ...
# | Epoch:  42 / 10000  | Loss:  0.5437  |
# Current loss:  0.5399019718170166  | , previous best loss:  0.5436854958534241  | saving best model ...
# | Epoch:  43 / 10000  | Loss:  0.5399  |
# Current loss:  0.5371876358985901  | , previous best loss:  0.5399019718170166  | saving best model ...
# | Epoch:  44 / 10000  | Loss:  0.5372  |
# Current loss:  0.534915030002594  | , previous best loss:  0.5371876358985901  | saving best model ...
# | Epoch:  45 / 10000  | Loss:  0.5349  |
# Current loss:  0.531815230846405  | , previous best loss:  0.534915030002594  | saving best model ...
# | Epoch:  46 / 10000  | Loss:  0.5318  |
# Current loss:  0.5283811092376709  | , previous best loss:  0.531815230846405  | saving best model ...
# | Epoch:  47 / 10000  | Loss:  0.5284  |
# Current loss:  0.5256921648979187  | , previous best loss:  0.5283811092376709  | saving best model ...
# | Epoch:  48 / 10000  | Loss:  0.5257  |
# Current loss:  0.5233209133148193  | , previous best loss:  0.5256921648979187  | saving best model ...
# | Epoch:  49 / 10000  | Loss:  0.5233  |
# Current loss:  0.5203626155853271  | , previous best loss:  0.5233209133148193  | saving best model ...
# | Epoch:  50 / 10000  | Loss:  0.5204  |
# Current loss:  0.5172280073165894  | , previous best loss:  0.5203626155853271  | saving best model ...
# | Epoch:  51 / 10000  | Loss:  0.5172  |
# Current loss:  0.5146490335464478  | , previous best loss:  0.5172280073165894  | saving best model ...
# | Epoch:  52 / 10000  | Loss:  0.5146  |
# Current loss:  0.5122098922729492  | , previous best loss:  0.5146490335464478  | saving best model ...
# | Epoch:  53 / 10000  | Loss:  0.5122  |
# Current loss:  0.5093342661857605  | , previous best loss:  0.5122098922729492  | saving best model ...
# | Epoch:  54 / 10000  | Loss:  0.5093  |
# Current loss:  0.5064412951469421  | , previous best loss:  0.5093342661857605  | saving best model ...
# | Epoch:  55 / 10000  | Loss:  0.5064  |
# Current loss:  0.5039568543434143  | , previous best loss:  0.5064412951469421  | saving best model ...
# | Epoch:  56 / 10000  | Loss:  0.504  |
# Current loss:  0.5014567971229553  | , previous best loss:  0.5039568543434143  | saving best model ...
# | Epoch:  57 / 10000  | Loss:  0.5015  |
# Current loss:  0.49866002798080444  | , previous best loss:  0.5014567971229553  | saving best model ...
# | Epoch:  58 / 10000  | Loss:  0.4987  |
# Current loss:  0.49598097801208496  | , previous best loss:  0.49866002798080444  | saving best model ...
# | Epoch:  59 / 10000  | Loss:  0.496  |
# Current loss:  0.49356043338775635  | , previous best loss:  0.49598097801208496  | saving best model ...
# | Epoch:  60 / 10000  | Loss:  0.4936  |
# Current loss:  0.49101126194000244  | , previous best loss:  0.49356043338775635  | saving best model ...
# | Epoch:  61 / 10000  | Loss:  0.491  |
# Current loss:  0.4883113503456116  | , previous best loss:  0.49101126194000244  | saving best model ...
# | Epoch:  62 / 10000  | Loss:  0.4883  |
# Current loss:  0.4857901632785797  | , previous best loss:  0.4883113503456116  | saving best model ...
# | Epoch:  63 / 10000  | Loss:  0.4858  |
# Current loss:  0.48336687684059143  | , previous best loss:  0.4857901632785797  | saving best model ...
# | Epoch:  64 / 10000  | Loss:  0.4834  |
# Current loss:  0.4807897210121155  | , previous best loss:  0.48336687684059143  | saving best model ...
# | Epoch:  65 / 10000  | Loss:  0.4808  |
# Current loss:  0.47821223735809326  | , previous best loss:  0.4807897210121155  | saving best model ...
# | Epoch:  66 / 10000  | Loss:  0.4782  |
# Current loss:  0.4757894277572632  | , previous best loss:  0.47821223735809326  | saving best model ...
# | Epoch:  67 / 10000  | Loss:  0.4758  |
# Current loss:  0.4733315706253052  | , previous best loss:  0.4757894277572632  | saving best model ...
# | Epoch:  68 / 10000  | Loss:  0.4733  |
# Current loss:  0.4707820415496826  | , previous best loss:  0.4733315706253052  | saving best model ...
# | Epoch:  69 / 10000  | Loss:  0.4708  |
# Current loss:  0.46832355856895447  | , previous best loss:  0.4707820415496826  | saving best model ...
# | Epoch:  70 / 10000  | Loss:  0.4683  |
# Current loss:  0.46592509746551514  | , previous best loss:  0.46832355856895447  | saving best model ...
# | Epoch:  71 / 10000  | Loss:  0.4659  |
# Current loss:  0.46344929933547974  | , previous best loss:  0.46592509746551514  | saving best model ...
# | Epoch:  72 / 10000  | Loss:  0.4634  |
# Current loss:  0.4609892964363098  | , previous best loss:  0.46344929933547974  | saving best model ...
# | Epoch:  73 / 10000  | Loss:  0.461  |
# Current loss:  0.45861414074897766  | , previous best loss:  0.4609892964363098  | saving best model ...
# | Epoch:  74 / 10000  | Loss:  0.4586  |
# Current loss:  0.4562089443206787  | , previous best loss:  0.45861414074897766  | saving best model ...
# | Epoch:  75 / 10000  | Loss:  0.4562  |
# Current loss:  0.45377734303474426  | , previous best loss:  0.4562089443206787  | saving best model ...
# | Epoch:  76 / 10000  | Loss:  0.4538  |
# Current loss:  0.45141443610191345  | , previous best loss:  0.45377734303474426  | saving best model ...
# | Epoch:  77 / 10000  | Loss:  0.4514  |
# Current loss:  0.449064165353775  | , previous best loss:  0.45141443610191345  | saving best model ...
# | Epoch:  78 / 10000  | Loss:  0.4491  |
# Current loss:  0.4466826915740967  | , previous best loss:  0.449064165353775  | saving best model ...
# | Epoch:  79 / 10000  | Loss:  0.4467  |
# Current loss:  0.44434595108032227  | , previous best loss:  0.4466826915740967  | saving best model ...
# | Epoch:  80 / 10000  | Loss:  0.4443  |
# Current loss:  0.4420420527458191  | , previous best loss:  0.44434595108032227  | saving best model ...
# | Epoch:  81 / 10000  | Loss:  0.442  |
# Current loss:  0.4397154450416565  | , previous best loss:  0.4420420527458191  | saving best model ...
# | Epoch:  82 / 10000  | Loss:  0.4397  |
# Current loss:  0.4374145269393921  | , previous best loss:  0.4397154450416565  | saving best model ...
# | Epoch:  83 / 10000  | Loss:  0.4374  |
# Current loss:  0.43515345454216003  | , previous best loss:  0.4374145269393921  | saving best model ...
# | Epoch:  84 / 10000  | Loss:  0.4352  |
# Current loss:  0.432883620262146  | , previous best loss:  0.43515345454216003  | saving best model ...
# | Epoch:  85 / 10000  | Loss:  0.4329  |
# Current loss:  0.4306314289569855  | , previous best loss:  0.432883620262146  | saving best model ...
# | Epoch:  86 / 10000  | Loss:  0.4306  |
# Current loss:  0.42841821908950806  | , previous best loss:  0.4306314289569855  | saving best model ...
# | Epoch:  87 / 10000  | Loss:  0.4284  |
# Current loss:  0.42620551586151123  | , previous best loss:  0.42841821908950806  | saving best model ...
# | Epoch:  88 / 10000  | Loss:  0.4262  |
# Current loss:  0.42400726675987244  | , previous best loss:  0.42620551586151123  | saving best model ...
# | Epoch:  89 / 10000  | Loss:  0.424  |
# Current loss:  0.4218456447124481  | , previous best loss:  0.42400726675987244  | saving best model ...
# | Epoch:  90 / 10000  | Loss:  0.4218  |
# Current loss:  0.41969215869903564  | , previous best loss:  0.4218456447124481  | saving best model ...
# | Epoch:  91 / 10000  | Loss:  0.4197  |
# Current loss:  0.4175550937652588  | , previous best loss:  0.41969215869903564  | saving best model ...
# | Epoch:  92 / 10000  | Loss:  0.4176  |
# Current loss:  0.4154519736766815  | , previous best loss:  0.4175550937652588  | saving best model ...
# | Epoch:  93 / 10000  | Loss:  0.4155  |
# Current loss:  0.41336071491241455  | , previous best loss:  0.4154519736766815  | saving best model ...
# | Epoch:  94 / 10000  | Loss:  0.4134  |
# Current loss:  0.41128814220428467  | , previous best loss:  0.41336071491241455  | saving best model ...
# | Epoch:  95 / 10000  | Loss:  0.4113  |
# Current loss:  0.40924733877182007  | , previous best loss:  0.41128814220428467  | saving best model ...
# | Epoch:  96 / 10000  | Loss:  0.4092  |
# Current loss:  0.40722134709358215  | , previous best loss:  0.40924733877182007  | saving best model ...
# | Epoch:  97 / 10000  | Loss:  0.4072  |
# Current loss:  0.4052172899246216  | , previous best loss:  0.40722134709358215  | saving best model ...
# | Epoch:  98 / 10000  | Loss:  0.4052  |
# Current loss:  0.40324270725250244  | , previous best loss:  0.4052172899246216  | saving best model ...
# | Epoch:  99 / 10000  | Loss:  0.4032  |
# Current loss:  0.4012840986251831  | , previous best loss:  0.40324270725250244  | saving best model ...
# | Epoch:  100 / 10000  | Loss:  0.4013  |
# Current loss:  0.39934951066970825  | , previous best loss:  0.4012840986251831  | saving best model ...
# | Epoch:  101 / 10000  | Loss:  0.3993  |
# Current loss:  0.3974417746067047  | , previous best loss:  0.39934951066970825  | saving best model ...
# | Epoch:  102 / 10000  | Loss:  0.3974  |
# Current loss:  0.3955514430999756  | , previous best loss:  0.3974417746067047  | saving best model ...
# | Epoch:  103 / 10000  | Loss:  0.3956  |
# Current loss:  0.39368653297424316  | , previous best loss:  0.3955514430999756  | saving best model ...
# | Epoch:  104 / 10000  | Loss:  0.3937  |
# Current loss:  0.3918452858924866  | , previous best loss:  0.39368653297424316  | saving best model ...
# | Epoch:  105 / 10000  | Loss:  0.3918  |
# Current loss:  0.390022337436676  | , previous best loss:  0.3918452858924866  | saving best model ...
# | Epoch:  106 / 10000  | Loss:  0.39  |
# Current loss:  0.38822466135025024  | , previous best loss:  0.390022337436676  | saving best model ...
# | Epoch:  107 / 10000  | Loss:  0.3882  |
# Current loss:  0.3864477276802063  | , previous best loss:  0.38822466135025024  | saving best model ...
# | Epoch:  108 / 10000  | Loss:  0.3864  |
# Current loss:  0.38469040393829346  | , previous best loss:  0.3864477276802063  | saving best model ...
# | Epoch:  109 / 10000  | Loss:  0.3847  |
# Current loss:  0.38295692205429077  | , previous best loss:  0.38469040393829346  | saving best model ...
# | Epoch:  110 / 10000  | Loss:  0.383  |
# Current loss:  0.38124188780784607  | , previous best loss:  0.38295692205429077  | saving best model ...
# | Epoch:  111 / 10000  | Loss:  0.3812  |
# Current loss:  0.37954747676849365  | , previous best loss:  0.38124188780784607  | saving best model ...
# | Epoch:  112 / 10000  | Loss:  0.3795  |
# Current loss:  0.37787437438964844  | , previous best loss:  0.37954747676849365  | saving best model ...
# | Epoch:  113 / 10000  | Loss:  0.3779  |
# Current loss:  0.37621912360191345  | , previous best loss:  0.37787437438964844  | saving best model ...
# | Epoch:  114 / 10000  | Loss:  0.3762  |
# Current loss:  0.37458479404449463  | , previous best loss:  0.37621912360191345  | saving best model ...
# | Epoch:  115 / 10000  | Loss:  0.3746  |
# Current loss:  0.37296921014785767  | , previous best loss:  0.37458479404449463  | saving best model ...
# | Epoch:  116 / 10000  | Loss:  0.373  |
# Current loss:  0.3713719844818115  | , previous best loss:  0.37296921014785767  | saving best model ...
# | Epoch:  117 / 10000  | Loss:  0.3714  |
# Current loss:  0.3697947859764099  | , previous best loss:  0.3713719844818115  | saving best model ...
# | Epoch:  118 / 10000  | Loss:  0.3698  |
# Current loss:  0.36823511123657227  | , previous best loss:  0.3697947859764099  | saving best model ...
# | Epoch:  119 / 10000  | Loss:  0.3682  |
# Current loss:  0.3666946291923523  | , previous best loss:  0.36823511123657227  | saving best model ...
# | Epoch:  120 / 10000  | Loss:  0.3667  |
# Current loss:  0.3651725649833679  | , previous best loss:  0.3666946291923523  | saving best model ...
# | Epoch:  121 / 10000  | Loss:  0.3652  |
# Current loss:  0.36366820335388184  | , previous best loss:  0.3651725649833679  | saving best model ...
# | Epoch:  122 / 10000  | Loss:  0.3637  |
# Current loss:  0.3621828556060791  | , previous best loss:  0.36366820335388184  | saving best model ...
# | Epoch:  123 / 10000  | Loss:  0.3622  |
# Current loss:  0.36071503162384033  | , previous best loss:  0.3621828556060791  | saving best model ...
# | Epoch:  124 / 10000  | Loss:  0.3607  |
# Current loss:  0.35926562547683716  | , previous best loss:  0.36071503162384033  | saving best model ...
# | Epoch:  125 / 10000  | Loss:  0.3593  |
# Current loss:  0.3578343689441681  | , previous best loss:  0.35926562547683716  | saving best model ...
# | Epoch:  126 / 10000  | Loss:  0.3578  |
# Current loss:  0.356420636177063  | , previous best loss:  0.3578343689441681  | saving best model ...
# | Epoch:  127 / 10000  | Loss:  0.3564  |
# Current loss:  0.35502544045448303  | , previous best loss:  0.356420636177063  | saving best model ...
# | Epoch:  128 / 10000  | Loss:  0.355  |
# Current loss:  0.3536476194858551  | , previous best loss:  0.35502544045448303  | saving best model ...
# | Epoch:  129 / 10000  | Loss:  0.3536  |
# Current loss:  0.3522879481315613  | , previous best loss:  0.3536476194858551  | saving best model ...
# | Epoch:  130 / 10000  | Loss:  0.3523  |
# Current loss:  0.35094594955444336  | , previous best loss:  0.3522879481315613  | saving best model ...
# | Epoch:  131 / 10000  | Loss:  0.3509  |
# Current loss:  0.34962156414985657  | , previous best loss:  0.35094594955444336  | saving best model ...
# | Epoch:  132 / 10000  | Loss:  0.3496  |
# Current loss:  0.34831497073173523  | , previous best loss:  0.34962156414985657  | saving best model ...
# | Epoch:  133 / 10000  | Loss:  0.3483  |
# Current loss:  0.34702563285827637  | , previous best loss:  0.34831497073173523  | saving best model ...
# | Epoch:  134 / 10000  | Loss:  0.347  |
# Current loss:  0.3457539677619934  | , previous best loss:  0.34702563285827637  | saving best model ...
# | Epoch:  135 / 10000  | Loss:  0.3458  |
# Current loss:  0.344499409198761  | , previous best loss:  0.3457539677619934  | saving best model ...
# | Epoch:  136 / 10000  | Loss:  0.3445  |
# Current loss:  0.34326204657554626  | , previous best loss:  0.344499409198761  | saving best model ...
# | Epoch:  137 / 10000  | Loss:  0.3433  |
# Current loss:  0.3420417010784149  | , previous best loss:  0.34326204657554626  | saving best model ...
# | Epoch:  138 / 10000  | Loss:  0.342  |
# Current loss:  0.3408381938934326  | , previous best loss:  0.3420417010784149  | saving best model ...
# | Epoch:  139 / 10000  | Loss:  0.3408  |
# Current loss:  0.3396508991718292  | , previous best loss:  0.3408381938934326  | saving best model ...
# | Epoch:  140 / 10000  | Loss:  0.3397  |
# Current loss:  0.33847859501838684  | , previous best loss:  0.3396508991718292  | saving best model ...
# | Epoch:  141 / 10000  | Loss:  0.3385  |
# Current loss:  0.3373223543167114  | , previous best loss:  0.33847859501838684  | saving best model ...
# | Epoch:  142 / 10000  | Loss:  0.3373  |
# Current loss:  0.33618196845054626  | , previous best loss:  0.3373223543167114  | saving best model ...
# | Epoch:  143 / 10000  | Loss:  0.3362  |
# Current loss:  0.33505743741989136  | , previous best loss:  0.33618196845054626  | saving best model ...
# | Epoch:  144 / 10000  | Loss:  0.3351  |
# Current loss:  0.3339483439922333  | , previous best loss:  0.33505743741989136  | saving best model ...
# | Epoch:  145 / 10000  | Loss:  0.3339  |
# Current loss:  0.33285465836524963  | , previous best loss:  0.3339483439922333  | saving best model ...
# | Epoch:  146 / 10000  | Loss:  0.3329  |
# Current loss:  0.33177584409713745  | , previous best loss:  0.33285465836524963  | saving best model ...
# | Epoch:  147 / 10000  | Loss:  0.3318  |
# Current loss:  0.33071190118789673  | , previous best loss:  0.33177584409713745  | saving best model ...
# | Epoch:  148 / 10000  | Loss:  0.3307  |
# Current loss:  0.3296623229980469  | , previous best loss:  0.33071190118789673  | saving best model ...
# | Epoch:  149 / 10000  | Loss:  0.3297  |
# Current loss:  0.328624963760376  | , previous best loss:  0.3296623229980469  | saving best model ...
# | Epoch:  150 / 10000  | Loss:  0.3286  |
# Current loss:  0.3275998532772064  | , previous best loss:  0.328624963760376  | saving best model ...
# | Epoch:  151 / 10000  | Loss:  0.3276  |
# Current loss:  0.32658788561820984  | , previous best loss:  0.3275998532772064  | saving best model ...
# | Epoch:  152 / 10000  | Loss:  0.3266  |
# Current loss:  0.3255890905857086  | , previous best loss:  0.32658788561820984  | saving best model ...
# | Epoch:  153 / 10000  | Loss:  0.3256  |
# Current loss:  0.3246031403541565  | , previous best loss:  0.3255890905857086  | saving best model ...
# | Epoch:  154 / 10000  | Loss:  0.3246  |
# Current loss:  0.32362979650497437  | , previous best loss:  0.3246031403541565  | saving best model ...
# | Epoch:  155 / 10000  | Loss:  0.3236  |
# Current loss:  0.3226689100265503  | , previous best loss:  0.32362979650497437  | saving best model ...
# | Epoch:  156 / 10000  | Loss:  0.3227  |
# Current loss:  0.3217201232910156  | , previous best loss:  0.3226689100265503  | saving best model ...
# | Epoch:  157 / 10000  | Loss:  0.3217  |
# Current loss:  0.3207833468914032  | , previous best loss:  0.3217201232910156  | saving best model ...
# | Epoch:  158 / 10000  | Loss:  0.3208  |
# Current loss:  0.31985828280448914  | , previous best loss:  0.3207833468914032  | saving best model ...
# | Epoch:  159 / 10000  | Loss:  0.3199  |
# Current loss:  0.3189448118209839  | , previous best loss:  0.31985828280448914  | saving best model ...
# | Epoch:  160 / 10000  | Loss:  0.3189  |
# Current loss:  0.3180426359176636  | , previous best loss:  0.3189448118209839  | saving best model ...
# | Epoch:  161 / 10000  | Loss:  0.318  |
# Current loss:  0.31715163588523865  | , previous best loss:  0.3180426359176636  | saving best model ...
# | Epoch:  162 / 10000  | Loss:  0.3172  |
# Current loss:  0.31627148389816284  | , previous best loss:  0.31715163588523865  | saving best model ...
# | Epoch:  163 / 10000  | Loss:  0.3163  |
# Current loss:  0.31540220975875854  | , previous best loss:  0.31627148389816284  | saving best model ...
# | Epoch:  164 / 10000  | Loss:  0.3154  |
# Current loss:  0.3145434558391571  | , previous best loss:  0.31540220975875854  | saving best model ...
# | Epoch:  165 / 10000  | Loss:  0.3145  |
# Current loss:  0.31369519233703613  | , previous best loss:  0.3145434558391571  | saving best model ...
# | Epoch:  166 / 10000  | Loss:  0.3137  |
# Current loss:  0.31285715103149414  | , previous best loss:  0.31369519233703613  | saving best model ...
# | Epoch:  167 / 10000  | Loss:  0.3129  |
# Current loss:  0.31202927231788635  | , previous best loss:  0.31285715103149414  | saving best model ...
# | Epoch:  168 / 10000  | Loss:  0.312  |
# Current loss:  0.3112112879753113  | , previous best loss:  0.31202927231788635  | saving best model ...
# | Epoch:  169 / 10000  | Loss:  0.3112  |
# Current loss:  0.3104032278060913  | , previous best loss:  0.3112112879753113  | saving best model ...
# | Epoch:  170 / 10000  | Loss:  0.3104  |
# Current loss:  0.30960479378700256  | , previous best loss:  0.3104032278060913  | saving best model ...
# | Epoch:  171 / 10000  | Loss:  0.3096  |
# Current loss:  0.30881595611572266  | , previous best loss:  0.30960479378700256  | saving best model ...
# | Epoch:  172 / 10000  | Loss:  0.3088  |
# Current loss:  0.30803653597831726  | , previous best loss:  0.30881595611572266  | saving best model ...
# | Epoch:  173 / 10000  | Loss:  0.308  |
# Current loss:  0.3072664141654968  | , previous best loss:  0.30803653597831726  | saving best model ...
# | Epoch:  174 / 10000  | Loss:  0.3073  |
# Current loss:  0.3065054416656494  | , previous best loss:  0.3072664141654968  | saving best model ...
# | Epoch:  175 / 10000  | Loss:  0.3065  |
# Current loss:  0.30575355887413025  | , previous best loss:  0.3065054416656494  | saving best model ...
# | Epoch:  176 / 10000  | Loss:  0.3058  |
# Current loss:  0.30500662326812744  | , previous best loss:  0.30575355887413025  | saving best model ...
# | Epoch:  177 / 10000  | Loss:  0.305  |
# Current loss:  0.30426445603370667  | , previous best loss:  0.30500662326812744  | saving best model ...
# | Epoch:  178 / 10000  | Loss:  0.3043  |
# Current loss:  0.30352896451950073  | , previous best loss:  0.30426445603370667  | saving best model ...
# | Epoch:  179 / 10000  | Loss:  0.3035  |
# Current loss:  0.3028029203414917  | , previous best loss:  0.30352896451950073  | saving best model ...
# | Epoch:  180 / 10000  | Loss:  0.3028  |
# Current loss:  0.30208319425582886  | , previous best loss:  0.3028029203414917  | saving best model ...
# | Epoch:  181 / 10000  | Loss:  0.3021  |
# Current loss:  0.30137452483177185  | , previous best loss:  0.30208319425582886  | saving best model ...
# | Epoch:  182 / 10000  | Loss:  0.3014  |
# Current loss:  0.3006705045700073  | , previous best loss:  0.30137452483177185  | saving best model ...
# | Epoch:  183 / 10000  | Loss:  0.3007  |
# Current loss:  0.29997703433036804  | , previous best loss:  0.3006705045700073  | saving best model ...
# | Epoch:  184 / 10000  | Loss:  0.3  |
# Current loss:  0.29928791522979736  | , previous best loss:  0.29997703433036804  | saving best model ...
# | Epoch:  185 / 10000  | Loss:  0.2993  |
# Current loss:  0.2986091375350952  | , previous best loss:  0.29928791522979736  | saving best model ...
# | Epoch:  186 / 10000  | Loss:  0.2986  |
# Current loss:  0.2979358434677124  | , previous best loss:  0.2986091375350952  | saving best model ...
# | Epoch:  187 / 10000  | Loss:  0.2979  |
# Current loss:  0.2972719073295593  | , previous best loss:  0.2979358434677124  | saving best model ...
# | Epoch:  188 / 10000  | Loss:  0.2973  |
# Current loss:  0.2966146469116211  | , previous best loss:  0.2972719073295593  | saving best model ...
# | Epoch:  189 / 10000  | Loss:  0.2966  |
# Current loss:  0.29596471786499023  | , previous best loss:  0.2966146469116211  | saving best model ...
# | Epoch:  190 / 10000  | Loss:  0.296  |
# Current loss:  0.2953225374221802  | , previous best loss:  0.29596471786499023  | saving best model ...
# | Epoch:  191 / 10000  | Loss:  0.2953  |
# Current loss:  0.29468661546707153  | , previous best loss:  0.2953225374221802  | saving best model ...
# | Epoch:  192 / 10000  | Loss:  0.2947  |
# Current loss:  0.2940594255924225  | , previous best loss:  0.29468661546707153  | saving best model ...
# | Epoch:  193 / 10000  | Loss:  0.2941  |
# Current loss:  0.29343825578689575  | , previous best loss:  0.2940594255924225  | saving best model ...
# | Epoch:  194 / 10000  | Loss:  0.2934  |
# Current loss:  0.292825311422348  | , previous best loss:  0.29343825578689575  | saving best model ...
# | Epoch:  195 / 10000  | Loss:  0.2928  |
# Current loss:  0.2922186553478241  | , previous best loss:  0.292825311422348  | saving best model ...
# | Epoch:  196 / 10000  | Loss:  0.2922  |
# Current loss:  0.2916187644004822  | , previous best loss:  0.2922186553478241  | saving best model ...
# | Epoch:  197 / 10000  | Loss:  0.2916  |
# Current loss:  0.29102566838264465  | , previous best loss:  0.2916187644004822  | saving best model ...
# | Epoch:  198 / 10000  | Loss:  0.291  |
# Current loss:  0.29043859243392944  | , previous best loss:  0.29102566838264465  | saving best model ...
# | Epoch:  199 / 10000  | Loss:  0.2904  |
# Current loss:  0.28985875844955444  | , previous best loss:  0.29043859243392944  | saving best model ...
# | Epoch:  200 / 10000  | Loss:  0.2899  |
# Current loss:  0.2892847955226898  | , previous best loss:  0.28985875844955444  | saving best model ...
# | Epoch:  201 / 10000  | Loss:  0.2893  |
# Current loss:  0.28871750831604004  | , previous best loss:  0.2892847955226898  | saving best model ...
# | Epoch:  202 / 10000  | Loss:  0.2887  |
# Current loss:  0.2881564497947693  | , previous best loss:  0.28871750831604004  | saving best model ...
# | Epoch:  203 / 10000  | Loss:  0.2882  |
# Current loss:  0.28760117292404175  | , previous best loss:  0.2881564497947693  | saving best model ...
# | Epoch:  204 / 10000  | Loss:  0.2876  |
# Current loss:  0.287052184343338  | , previous best loss:  0.28760117292404175  | saving best model ...
# | Epoch:  205 / 10000  | Loss:  0.2871  |
# Current loss:  0.2865087389945984  | , previous best loss:  0.287052184343338  | saving best model ...
# | Epoch:  206 / 10000  | Loss:  0.2865  |
# Current loss:  0.28597134351730347  | , previous best loss:  0.2865087389945984  | saving best model ...
# | Epoch:  207 / 10000  | Loss:  0.286  |
# Current loss:  0.2854396104812622  | , previous best loss:  0.28597134351730347  | saving best model ...
# | Epoch:  208 / 10000  | Loss:  0.2854  |
# Current loss:  0.2849133312702179  | , previous best loss:  0.2854396104812622  | saving best model ...
# | Epoch:  209 / 10000  | Loss:  0.2849  |
# Current loss:  0.2843928337097168  | , previous best loss:  0.2849133312702179  | saving best model ...
# | Epoch:  210 / 10000  | Loss:  0.2844  |
# Current loss:  0.28387749195098877  | , previous best loss:  0.2843928337097168  | saving best model ...
# | Epoch:  211 / 10000  | Loss:  0.2839  |
# Current loss:  0.2833676040172577  | , previous best loss:  0.28387749195098877  | saving best model ...
# | Epoch:  212 / 10000  | Loss:  0.2834  |
# Current loss:  0.28286316990852356  | , previous best loss:  0.2833676040172577  | saving best model ...
# | Epoch:  213 / 10000  | Loss:  0.2829  |
# Current loss:  0.28236374258995056  | , previous best loss:  0.28286316990852356  | saving best model ...
# | Epoch:  214 / 10000  | Loss:  0.2824  |
# Current loss:  0.2818696200847626  | , previous best loss:  0.28236374258995056  | saving best model ...
# | Epoch:  215 / 10000  | Loss:  0.2819  |
# Current loss:  0.2813805639743805  | , previous best loss:  0.2818696200847626  | saving best model ...
# | Epoch:  216 / 10000  | Loss:  0.2814  |
# Current loss:  0.28089630603790283  | , previous best loss:  0.2813805639743805  | saving best model ...
# | Epoch:  217 / 10000  | Loss:  0.2809  |
# Current loss:  0.2804170846939087  | , previous best loss:  0.28089630603790283  | saving best model ...
# | Epoch:  218 / 10000  | Loss:  0.2804  |
# Current loss:  0.27994266152381897  | , previous best loss:  0.2804170846939087  | saving best model ...
# | Epoch:  219 / 10000  | Loss:  0.2799  |
# Current loss:  0.2794730067253113  | , previous best loss:  0.27994266152381897  | saving best model ...
# | Epoch:  220 / 10000  | Loss:  0.2795  |
# Current loss:  0.2790081202983856  | , previous best loss:  0.2794730067253113  | saving best model ...
# | Epoch:  221 / 10000  | Loss:  0.279  |
# Current loss:  0.27854782342910767  | , previous best loss:  0.2790081202983856  | saving best model ...
# | Epoch:  222 / 10000  | Loss:  0.2785  |
# Current loss:  0.27809205651283264  | , previous best loss:  0.27854782342910767  | saving best model ...
# | Epoch:  223 / 10000  | Loss:  0.2781  |
# Current loss:  0.2776408791542053  | , previous best loss:  0.27809205651283264  | saving best model ...
# | Epoch:  224 / 10000  | Loss:  0.2776  |
# Current loss:  0.277194082736969  | , previous best loss:  0.2776408791542053  | saving best model ...
# | Epoch:  225 / 10000  | Loss:  0.2772  |
# Current loss:  0.27675163745880127  | , previous best loss:  0.277194082736969  | saving best model ...
# | Epoch:  226 / 10000  | Loss:  0.2768  |
# Current loss:  0.27631354331970215  | , previous best loss:  0.27675163745880127  | saving best model ...
# | Epoch:  227 / 10000  | Loss:  0.2763  |
# Current loss:  0.2758796811103821  | , previous best loss:  0.27631354331970215  | saving best model ...
# | Epoch:  228 / 10000  | Loss:  0.2759  |
# Current loss:  0.2754499912261963  | , previous best loss:  0.2758796811103821  | saving best model ...
# | Epoch:  229 / 10000  | Loss:  0.2754  |
# Current loss:  0.2750244140625  | , previous best loss:  0.2754499912261963  | saving best model ...
# | Epoch:  230 / 10000  | Loss:  0.275  |
# Current loss:  0.2746029496192932  | , previous best loss:  0.2750244140625  | saving best model ...
# | Epoch:  231 / 10000  | Loss:  0.2746  |
# Current loss:  0.27418479323387146  | , previous best loss:  0.2746029496192932  | saving best model ...
# | Epoch:  232 / 10000  | Loss:  0.2742  |
# Current loss:  0.2737698554992676  | , previous best loss:  0.27418479323387146  | saving best model ...
# | Epoch:  233 / 10000  | Loss:  0.2738  |
# Current loss:  0.27335071563720703  | , previous best loss:  0.2737698554992676  | saving best model ...
# | Epoch:  234 / 10000  | Loss:  0.2734  |
# Current loss:  0.2729361355304718  | , previous best loss:  0.27335071563720703  | saving best model ...
# | Epoch:  235 / 10000  | Loss:  0.2729  |
# Current loss:  0.27253037691116333  | , previous best loss:  0.2729361355304718  | saving best model ...
# | Epoch:  236 / 10000  | Loss:  0.2725  |
# Current loss:  0.2721259593963623  | , previous best loss:  0.27253037691116333  | saving best model ...
# | Epoch:  237 / 10000  | Loss:  0.2721  |
# Current loss:  0.27172279357910156  | , previous best loss:  0.2721259593963623  | saving best model ...
# | Epoch:  238 / 10000  | Loss:  0.2717  |
# Current loss:  0.27132636308670044  | , previous best loss:  0.27172279357910156  | saving best model ...
# | Epoch:  239 / 10000  | Loss:  0.2713  |
# Current loss:  0.2709346413612366  | , previous best loss:  0.27132636308670044  | saving best model ...
# | Epoch:  240 / 10000  | Loss:  0.2709  |
# Current loss:  0.27054399251937866  | , previous best loss:  0.2709346413612366  | saving best model ...
# | Epoch:  241 / 10000  | Loss:  0.2705  |
# Current loss:  0.27015694975852966  | , previous best loss:  0.27054399251937866  | saving best model ...
# | Epoch:  242 / 10000  | Loss:  0.2702  |
# Current loss:  0.2697755694389343  | , previous best loss:  0.27015694975852966  | saving best model ...
# | Epoch:  243 / 10000  | Loss:  0.2698  |
# Current loss:  0.2693972885608673  | , previous best loss:  0.2697755694389343  | saving best model ...
# | Epoch:  244 / 10000  | Loss:  0.2694  |
# Current loss:  0.26901960372924805  | , previous best loss:  0.2693972885608673  | saving best model ...
# | Epoch:  245 / 10000  | Loss:  0.269  |
# Current loss:  0.26864659786224365  | , previous best loss:  0.26901960372924805  | saving best model ...
# | Epoch:  246 / 10000  | Loss:  0.2686  |
# Current loss:  0.2682751715183258  | , previous best loss:  0.26864659786224365  | saving best model ...
# | Epoch:  247 / 10000  | Loss:  0.2683  |
# Current loss:  0.26790568232536316  | , previous best loss:  0.2682751715183258  | saving best model ...
# | Epoch:  248 / 10000  | Loss:  0.2679  |
# Current loss:  0.2675408720970154  | , previous best loss:  0.26790568232536316  | saving best model ...
# | Epoch:  249 / 10000  | Loss:  0.2675  |
# Current loss:  0.26718050241470337  | , previous best loss:  0.2675408720970154  | saving best model ...
# | Epoch:  250 / 10000  | Loss:  0.2672  |
# Current loss:  0.26682254672050476  | , previous best loss:  0.26718050241470337  | saving best model ...
# | Epoch:  251 / 10000  | Loss:  0.2668  |
# Current loss:  0.26646631956100464  | , previous best loss:  0.26682254672050476  | saving best model ...
# | Epoch:  252 / 10000  | Loss:  0.2665  |
# Current loss:  0.2661133408546448  | , previous best loss:  0.26646631956100464  | saving best model ...
# | Epoch:  253 / 10000  | Loss:  0.2661  |
# Current loss:  0.26576465368270874  | , previous best loss:  0.2661133408546448  | saving best model ...
# | Epoch:  254 / 10000  | Loss:  0.2658  |
# Current loss:  0.2654195725917816  | , previous best loss:  0.26576465368270874  | saving best model ...
# | Epoch:  255 / 10000  | Loss:  0.2654  |
# Current loss:  0.26507681608200073  | , previous best loss:  0.2654195725917816  | saving best model ...
# | Epoch:  256 / 10000  | Loss:  0.2651  |
# Current loss:  0.2647360861301422  | , previous best loss:  0.26507681608200073  | saving best model ...
# | Epoch:  257 / 10000  | Loss:  0.2647  |
# Current loss:  0.2643980383872986  | , previous best loss:  0.2647360861301422  | saving best model ...
# | Epoch:  258 / 10000  | Loss:  0.2644  |
# Current loss:  0.26406329870224  | , previous best loss:  0.2643980383872986  | saving best model ...
# | Epoch:  259 / 10000  | Loss:  0.2641  |
# Current loss:  0.26373183727264404  | , previous best loss:  0.26406329870224  | saving best model ...
# | Epoch:  260 / 10000  | Loss:  0.2637  |
# Current loss:  0.26340314745903015  | , previous best loss:  0.26373183727264404  | saving best model ...
# | Epoch:  261 / 10000  | Loss:  0.2634  |
# Current loss:  0.2630767524242401  | , previous best loss:  0.26340314745903015  | saving best model ...
# | Epoch:  262 / 10000  | Loss:  0.2631  |
# Current loss:  0.2627525329589844  | , previous best loss:  0.2630767524242401  | saving best model ...
# | Epoch:  263 / 10000  | Loss:  0.2628  |
# Current loss:  0.2624305784702301  | , previous best loss:  0.2627525329589844  | saving best model ...
# | Epoch:  264 / 10000  | Loss:  0.2624  |
# Current loss:  0.2621111273765564  | , previous best loss:  0.2624305784702301  | saving best model ...
# | Epoch:  265 / 10000  | Loss:  0.2621  |
# Current loss:  0.2617942988872528  | , previous best loss:  0.2621111273765564  | saving best model ...
# | Epoch:  266 / 10000  | Loss:  0.2618  |
# Current loss:  0.26148006319999695  | , previous best loss:  0.2617942988872528  | saving best model ...
# | Epoch:  267 / 10000  | Loss:  0.2615  |
# Current loss:  0.26116830110549927  | , previous best loss:  0.26148006319999695  | saving best model ...
# | Epoch:  268 / 10000  | Loss:  0.2612  |
# Current loss:  0.2608588933944702  | , previous best loss:  0.26116830110549927  | saving best model ...
# | Epoch:  269 / 10000  | Loss:  0.2609  |
# Current loss:  0.2605517506599426  | , previous best loss:  0.2608588933944702  | saving best model ...
# | Epoch:  270 / 10000  | Loss:  0.2606  |
# Current loss:  0.26024699211120605  | , previous best loss:  0.2605517506599426  | saving best model ...
# | Epoch:  271 / 10000  | Loss:  0.2602  |
# Current loss:  0.25994449853897095  | , previous best loss:  0.26024699211120605  | saving best model ...
# | Epoch:  272 / 10000  | Loss:  0.2599  |
# Current loss:  0.2596442997455597  | , previous best loss:  0.25994449853897095  | saving best model ...
# | Epoch:  273 / 10000  | Loss:  0.2596  |
# Current loss:  0.25934654474258423  | , previous best loss:  0.2596442997455597  | saving best model ...
# | Epoch:  274 / 10000  | Loss:  0.2593  |
# Current loss:  0.25905153155326843  | , previous best loss:  0.25934654474258423  | saving best model ...
# | Epoch:  275 / 10000  | Loss:  0.2591  |
# Current loss:  0.2587597966194153  | , previous best loss:  0.25905153155326843  | saving best model ...
# | Epoch:  276 / 10000  | Loss:  0.2588  |
# Current loss:  0.25847259163856506  | , previous best loss:  0.2587597966194153  | saving best model ...
# | Epoch:  277 / 10000  | Loss:  0.2585  |
# Current loss:  0.25819283723831177  | , previous best loss:  0.25847259163856506  | saving best model ...
# | Epoch:  278 / 10000  | Loss:  0.2582  |
# Current loss:  0.2579270899295807  | , previous best loss:  0.25819283723831177  | saving best model ...
# | Epoch:  279 / 10000  | Loss:  0.2579  |
# Current loss:  0.25769031047821045  | , previous best loss:  0.2579270899295807  | saving best model ...
# | Epoch:  280 / 10000  | Loss:  0.2577  |
# Current loss:  0.2575150728225708  | , previous best loss:  0.25769031047821045  | saving best model ...
# | Epoch:  281 / 10000  | Loss:  0.2575  |
# | Epoch:  282 / 10000  | Loss:  0.2575  |
# | Epoch:  283 / 10000  | Loss:  0.2576  |
# | Epoch:  284 / 10000  | Loss:  0.2577  |
# Current loss:  0.2573535740375519  | , previous best loss:  0.2575150728225708  | saving best model ...
# | Epoch:  285 / 10000  | Loss:  0.2574  |
# Current loss:  0.2564517855644226  | , previous best loss:  0.2573535740375519  | saving best model ...
# | Epoch:  286 / 10000  | Loss:  0.2565  |
# Current loss:  0.2556880712509155  | , previous best loss:  0.2564517855644226  | saving best model ...
# | Epoch:  287 / 10000  | Loss:  0.2557  |
# | Epoch:  288 / 10000  | Loss:  0.2556  |
# | Epoch:  289 / 10000  | Loss:  0.2558  |
# Current loss:  0.25548750162124634  | , previous best loss:  0.2556880712509155  | saving best model ...
# | Epoch:  290 / 10000  | Loss:  0.2555  |
# Current loss:  0.25477850437164307  | , previous best loss:  0.25548750162124634  | saving best model ...
# | Epoch:  291 / 10000  | Loss:  0.2548  |
# Current loss:  0.25439533591270447  | , previous best loss:  0.25477850437164307  | saving best model ...
# | Epoch:  292 / 10000  | Loss:  0.2544  |
# | Epoch:  293 / 10000  | Loss:  0.2544  |
# Current loss:  0.25431758165359497  | , previous best loss:  0.25439533591270447  | saving best model ...
# | Epoch:  294 / 10000  | Loss:  0.2543  |
# Current loss:  0.2538182735443115  | , previous best loss:  0.25431758165359497  | saving best model ...
# | Epoch:  295 / 10000  | Loss:  0.2538  |
# Current loss:  0.2533683180809021  | , previous best loss:  0.2538182735443115  | saving best model ...
# | Epoch:  296 / 10000  | Loss:  0.2534  |
# Current loss:  0.2532534599304199  | , previous best loss:  0.2533683180809021  | saving best model ...
# | Epoch:  297 / 10000  | Loss:  0.2533  |
# | Epoch:  298 / 10000  | Loss:  0.2532  |
# Current loss:  0.25284069776535034  | , previous best loss:  0.2532534599304199  | saving best model ...
# | Epoch:  299 / 10000  | Loss:  0.2528  |
# Current loss:  0.2524144649505615  | , previous best loss:  0.25284069776535034  | saving best model ...
# | Epoch:  300 / 10000  | Loss:  0.2524  |
# Current loss:  0.2521820068359375  | , previous best loss:  0.2524144649505615  | saving best model ...
# | Epoch:  301 / 10000  | Loss:  0.2522  |
# Current loss:  0.2520785927772522  | , previous best loss:  0.2521820068359375  | saving best model ...
# | Epoch:  302 / 10000  | Loss:  0.2521  |
# Current loss:  0.2518622577190399  | , previous best loss:  0.2520785927772522  | saving best model ...
# | Epoch:  303 / 10000  | Loss:  0.2519  |
# Current loss:  0.2515071928501129  | , previous best loss:  0.2518622577190399  | saving best model ...
# | Epoch:  304 / 10000  | Loss:  0.2515  |
# Current loss:  0.2512008249759674  | , previous best loss:  0.2515071928501129  | saving best model ...
# | Epoch:  305 / 10000  | Loss:  0.2512  |
# Current loss:  0.2510260343551636  | , previous best loss:  0.2512008249759674  | saving best model ...
# | Epoch:  306 / 10000  | Loss:  0.251  |
# Current loss:  0.2508678734302521  | , previous best loss:  0.2510260343551636  | saving best model ...
# | Epoch:  307 / 10000  | Loss:  0.2509  |
# Current loss:  0.2506156265735626  | , previous best loss:  0.2508678734302521  | saving best model ...
# | Epoch:  308 / 10000  | Loss:  0.2506  |
# Current loss:  0.2503076195716858  | , previous best loss:  0.2506156265735626  | saving best model ...
# | Epoch:  309 / 10000  | Loss:  0.2503  |
# Current loss:  0.25005042552948  | , previous best loss:  0.2503076195716858  | saving best model ...
# | Epoch:  310 / 10000  | Loss:  0.2501  |
# Current loss:  0.24986597895622253  | , previous best loss:  0.25005042552948  | saving best model ...
# | Epoch:  311 / 10000  | Loss:  0.2499  |
# Current loss:  0.24968551099300385  | , previous best loss:  0.24986597895622253  | saving best model ...
# | Epoch:  312 / 10000  | Loss:  0.2497  |
# Current loss:  0.24945273995399475  | , previous best loss:  0.24968551099300385  | saving best model ...
# | Epoch:  313 / 10000  | Loss:  0.2495  |
# Current loss:  0.24918395280838013  | , previous best loss:  0.24945273995399475  | saving best model ...
# | Epoch:  314 / 10000  | Loss:  0.2492  |
# Current loss:  0.24893364310264587  | , previous best loss:  0.24918395280838013  | saving best model ...
# | Epoch:  315 / 10000  | Loss:  0.2489  |
# Current loss:  0.24872617423534393  | , previous best loss:  0.24893364310264587  | saving best model ...
# | Epoch:  316 / 10000  | Loss:  0.2487  |
# Current loss:  0.24853920936584473  | , previous best loss:  0.24872617423534393  | saving best model ...
# | Epoch:  317 / 10000  | Loss:  0.2485  |
# Current loss:  0.24833792448043823  | , previous best loss:  0.24853920936584473  | saving best model ...
# | Epoch:  318 / 10000  | Loss:  0.2483  |
# Current loss:  0.24810954928398132  | , previous best loss:  0.24833792448043823  | saving best model ...
# | Epoch:  319 / 10000  | Loss:  0.2481  |
# Current loss:  0.24786898493766785  | , previous best loss:  0.24810954928398132  | saving best model ...
# | Epoch:  320 / 10000  | Loss:  0.2479  |
# Current loss:  0.2476382851600647  | , previous best loss:  0.24786898493766785  | saving best model ...
# | Epoch:  321 / 10000  | Loss:  0.2476  |
# Current loss:  0.2474277913570404  | , previous best loss:  0.2476382851600647  | saving best model ...
# | Epoch:  322 / 10000  | Loss:  0.2474  |
# Current loss:  0.2472318708896637  | , previous best loss:  0.2474277913570404  | saving best model ...
# | Epoch:  323 / 10000  | Loss:  0.2472  |
# Current loss:  0.24703791737556458  | , previous best loss:  0.2472318708896637  | saving best model ...
# | Epoch:  324 / 10000  | Loss:  0.247  |
# Current loss:  0.24683675169944763  | , previous best loss:  0.24703791737556458  | saving best model ...
# | Epoch:  325 / 10000  | Loss:  0.2468  |
# Current loss:  0.24662616848945618  | , previous best loss:  0.24683675169944763  | saving best model ...
# | Epoch:  326 / 10000  | Loss:  0.2466  |
# Current loss:  0.24641001224517822  | , previous best loss:  0.24662616848945618  | saving best model ...
# | Epoch:  327 / 10000  | Loss:  0.2464  |
# Current loss:  0.24619384109973907  | , previous best loss:  0.24641001224517822  | saving best model ...
# | Epoch:  328 / 10000  | Loss:  0.2462  |
# Current loss:  0.2459820806980133  | , previous best loss:  0.24619384109973907  | saving best model ...
# | Epoch:  329 / 10000  | Loss:  0.246  |
# Current loss:  0.24577638506889343  | , previous best loss:  0.2459820806980133  | saving best model ...
# | Epoch:  330 / 10000  | Loss:  0.2458  |
# Current loss:  0.24557635188102722  | , previous best loss:  0.24577638506889343  | saving best model ...
# | Epoch:  331 / 10000  | Loss:  0.2456  |
# Current loss:  0.24538078904151917  | , previous best loss:  0.24557635188102722  | saving best model ...
# | Epoch:  332 / 10000  | Loss:  0.2454  |
# Current loss:  0.24518844485282898  | , previous best loss:  0.24538078904151917  | saving best model ...
# | Epoch:  333 / 10000  | Loss:  0.2452  |
# Current loss:  0.244998961687088  | , previous best loss:  0.24518844485282898  | saving best model ...
# | Epoch:  334 / 10000  | Loss:  0.245  |
# Current loss:  0.24481254816055298  | , previous best loss:  0.244998961687088  | saving best model ...
# | Epoch:  335 / 10000  | Loss:  0.2448  |
# Current loss:  0.2446308434009552  | , previous best loss:  0.24481254816055298  | saving best model ...
# | Epoch:  336 / 10000  | Loss:  0.2446  |
# Current loss:  0.24445626139640808  | , previous best loss:  0.2446308434009552  | saving best model ...
# | Epoch:  337 / 10000  | Loss:  0.2445  |
# Current loss:  0.24429400265216827  | , previous best loss:  0.24445626139640808  | saving best model ...
# | Epoch:  338 / 10000  | Loss:  0.2443  |
# Current loss:  0.2441520392894745  | , previous best loss:  0.24429400265216827  | saving best model ...
# | Epoch:  339 / 10000  | Loss:  0.2442  |
# Current loss:  0.2440449595451355  | , previous best loss:  0.2441520392894745  | saving best model ...
# | Epoch:  340 / 10000  | Loss:  0.244  |
# | Epoch:  341 / 10000  | Loss:  0.244  |
# | Epoch:  342 / 10000  | Loss:  0.244  |
# | Epoch:  343 / 10000  | Loss:  0.2441  |
# | Epoch:  344 / 10000  | Loss:  0.2443  |
# | Epoch:  345 / 10000  | Loss:  0.2441  |
# Current loss:  0.24367623031139374  | , previous best loss:  0.2440449595451355  | saving best model ...
# | Epoch:  346 / 10000  | Loss:  0.2437  |
# Current loss:  0.2429361641407013  | , previous best loss:  0.24367623031139374  | saving best model ...
# | Epoch:  347 / 10000  | Loss:  0.2429  |
# Current loss:  0.24238461256027222  | , previous best loss:  0.2429361641407013  | saving best model ...
# | Epoch:  348 / 10000  | Loss:  0.2424  |
# Current loss:  0.24225175380706787  | , previous best loss:  0.24238461256027222  | saving best model ...
# | Epoch:  349 / 10000  | Loss:  0.2423  |
# | Epoch:  350 / 10000  | Loss:  0.2424  |
# | Epoch:  351 / 10000  | Loss:  0.2425  |
# Current loss:  0.24222210049629211  | , previous best loss:  0.24225175380706787  | saving best model ...
# | Epoch:  352 / 10000  | Loss:  0.2422  |
# Current loss:  0.24174979329109192  | , previous best loss:  0.24222210049629211  | saving best model ...
# | Epoch:  353 / 10000  | Loss:  0.2417  |
# Current loss:  0.2413371503353119  | , previous best loss:  0.24174979329109192  | saving best model ...
# | Epoch:  354 / 10000  | Loss:  0.2413  |
# Current loss:  0.24117004871368408  | , previous best loss:  0.2413371503353119  | saving best model ...
# | Epoch:  355 / 10000  | Loss:  0.2412  |
# | Epoch:  356 / 10000  | Loss:  0.2412  |
# | Epoch:  357 / 10000  | Loss:  0.2412  |
# Current loss:  0.24098500609397888  | , previous best loss:  0.24117004871368408  | saving best model ...
# | Epoch:  358 / 10000  | Loss:  0.241  |
# Current loss:  0.2406383454799652  | , previous best loss:  0.24098500609397888  | saving best model ...
# | Epoch:  359 / 10000  | Loss:  0.2406  |
# Current loss:  0.2403220534324646  | , previous best loss:  0.2406383454799652  | saving best model ...
# | Epoch:  360 / 10000  | Loss:  0.2403  |
# Current loss:  0.2401426136493683  | , previous best loss:  0.2403220534324646  | saving best model ...
# | Epoch:  361 / 10000  | Loss:  0.2401  |
# | Epoch:  362 / 10000  | Loss:  0.2401  |
# | Epoch:  363 / 10000  | Loss:  0.24  |
# Current loss:  0.23985780775547028  | , previous best loss:  0.2401426136493683  | saving best model ...
# | Epoch:  364 / 10000  | Loss:  0.2399  |
# Current loss:  0.23962357640266418  | , previous best loss:  0.23985780775547028  | saving best model ...
# | Epoch:  365 / 10000  | Loss:  0.2396  |
# Current loss:  0.2393593043088913  | , previous best loss:  0.23962357640266418  | saving best model ...
# | Epoch:  366 / 10000  | Loss:  0.2394  |
# Current loss:  0.23915493488311768  | , previous best loss:  0.2393593043088913  | saving best model ...
# | Epoch:  367 / 10000  | Loss:  0.2392  |
# Current loss:  0.2390204817056656  | , previous best loss:  0.23915493488311768  | saving best model ...
# | Epoch:  368 / 10000  | Loss:  0.239  |
# | Epoch:  369 / 10000  | Loss:  0.2389  |
# Current loss:  0.23882126808166504  | , previous best loss:  0.2390204817056656  | saving best model ...
# | Epoch:  370 / 10000  | Loss:  0.2388  |
# Current loss:  0.23866568505764008  | , previous best loss:  0.23882126808166504  | saving best model ...
# | Epoch:  371 / 10000  | Loss:  0.2387  |
# Current loss:  0.23847602307796478  | , previous best loss:  0.23866568505764008  | saving best model ...
# | Epoch:  372 / 10000  | Loss:  0.2385  |
# Current loss:  0.2382613867521286  | , previous best loss:  0.23847602307796478  | saving best model ...
# | Epoch:  373 / 10000  | Loss:  0.2383  |
# Current loss:  0.23806430399417877  | , previous best loss:  0.2382613867521286  | saving best model ...
# | Epoch:  374 / 10000  | Loss:  0.2381  |
# Current loss:  0.2378949075937271  | , previous best loss:  0.23806430399417877  | saving best model ...
# | Epoch:  375 / 10000  | Loss:  0.2379  |
# Current loss:  0.23775030672550201  | , previous best loss:  0.2378949075937271  | saving best model ...
# | Epoch:  376 / 10000  | Loss:  0.2378  |
# Current loss:  0.23762154579162598  | , previous best loss:  0.23775030672550201  | saving best model ...
# | Epoch:  377 / 10000  | Loss:  0.2376  |
# Current loss:  0.23748821020126343  | , previous best loss:  0.23762154579162598  | saving best model ...
# | Epoch:  378 / 10000  | Loss:  0.2375  |
# Current loss:  0.237351194024086  | , previous best loss:  0.23748821020126343  | saving best model ...
# | Epoch:  379 / 10000  | Loss:  0.2374  |
# Current loss:  0.2372015118598938  | , previous best loss:  0.237351194024086  | saving best model ...
# | Epoch:  380 / 10000  | Loss:  0.2372  |
# Current loss:  0.23704715073108673  | , previous best loss:  0.2372015118598938  | saving best model ...
# | Epoch:  381 / 10000  | Loss:  0.237  |
# Current loss:  0.2368859052658081  | , previous best loss:  0.23704715073108673  | saving best model ...
# | Epoch:  382 / 10000  | Loss:  0.2369  |
# Current loss:  0.23672443628311157  | , previous best loss:  0.2368859052658081  | saving best model ...
# | Epoch:  383 / 10000  | Loss:  0.2367  |
# Current loss:  0.23656253516674042  | , previous best loss:  0.23672443628311157  | saving best model ...
# | Epoch:  384 / 10000  | Loss:  0.2366  |
# Current loss:  0.23640243709087372  | , previous best loss:  0.23656253516674042  | saving best model ...
# | Epoch:  385 / 10000  | Loss:  0.2364  |
# Current loss:  0.23624545335769653  | , previous best loss:  0.23640243709087372  | saving best model ...
# | Epoch:  386 / 10000  | Loss:  0.2362  |
# Current loss:  0.23608995974063873  | , previous best loss:  0.23624545335769653  | saving best model ...
# | Epoch:  387 / 10000  | Loss:  0.2361  |
# Current loss:  0.2359388768672943  | , previous best loss:  0.23608995974063873  | saving best model ...
# | Epoch:  388 / 10000  | Loss:  0.2359  |
# Current loss:  0.23579086363315582  | , previous best loss:  0.2359388768672943  | saving best model ...
# | Epoch:  389 / 10000  | Loss:  0.2358  |
# Current loss:  0.23564478754997253  | , previous best loss:  0.23579086363315582  | saving best model ...
# | Epoch:  390 / 10000  | Loss:  0.2356  |
# Current loss:  0.23550023138523102  | , previous best loss:  0.23564478754997253  | saving best model ...
# | Epoch:  391 / 10000  | Loss:  0.2355  |
# | Epoch:  429 / 10000  | Loss:  0.2333  |
# | Epoch:  430 / 10000  | Loss:  0.2333  |
# | Epoch:  431 / 10000  | Loss:  0.2333  |
# | Epoch:  432 / 10000  | Loss:  0.2333  |
# Current loss:  0.23312988877296448  | , previous best loss:  0.23325884342193604  | saving best model ...
# | Epoch:  433 / 10000  | Loss:  0.2331  |
# | Epoch:  434 / 10000  | Loss:  0.2331  |
# | Epoch:  435 / 10000  | Loss:  0.2331  |
# | Epoch:  436 / 10000  | Loss:  0.2331  |
# Current loss:  0.23297715187072754  | , previous best loss:  0.23312988877296448  | saving best model ...
# | Epoch:  437 / 10000  | Loss:  0.233  |
# | Epoch:  438 / 10000  | Loss:  0.2329  |
# | Epoch:  439 / 10000  | Loss:  0.2329  |
# | Epoch:  440 / 10000  | Loss:  0.2329  |
# | Epoch:  441 / 10000  | Loss:  0.2328  |
# Learning rate reduce to  0.0004
# | Epoch:  442 / 10000  | Loss:  0.2327  |
# | Epoch:  443 / 10000  | Loss:  0.2329  |
# Current loss:  0.23265454173088074  | , previous best loss:  0.23297715187072754  | saving best model ...
# | Epoch:  444 / 10000  | Loss:  0.2327  |
# | Epoch:  445 / 10000  | Loss:  0.2328  |
# | Epoch:  446 / 10000  | Loss:  0.2327  |
# | Epoch:  447 / 10000  | Loss:  0.2326  |
# | Epoch:  448 / 10000  | Loss:  0.2326  |
# Learning rate reduce to  8e-05
# | Epoch:  449 / 10000  | Loss:  0.2326  |
# | Epoch:  450 / 10000  | Loss:  0.2326  |
# | Epoch:  451 / 10000  | Loss:  0.2325  |
# | Epoch:  452 / 10000  | Loss:  0.2326  |
# | Epoch:  453 / 10000  | Loss:  0.2326  |
# Learning rate reduce to  1.6000000000000003e-05
# | Epoch:  454 / 10000  | Loss:  0.2326  |
# | Epoch:  455 / 10000  | Loss:  0.2325  |
# | Epoch:  456 / 10000  | Loss:  0.2325  |
# | Epoch:  457 / 10000  | Loss:  0.2325  |
# | Epoch:  458 / 10000  | Loss:  0.2325  |
# Learning rate reduce to  3.2000000000000007e-06
# | Epoch:  459 / 10000  | Loss:  0.2325  |
# | Epoch:  460 / 10000  | Loss:  0.2325  |
# | Epoch:  461 / 10000  | Loss:  0.2325  |
# | Epoch:  462 / 10000  | Loss:  0.2325  |
# | Epoch:  463 / 10000  | Loss:  0.2325  |
# Learning rate reduce to  6.400000000000002e-07
# | Epoch:  464 / 10000  | Loss:  0.2325  |
# Convergence!

# %%
with torch.no_grad():
    eval_model = MPSv3(input_dim = Fin, degree = dg, num_knots = nk, num_neurons = nm, output_dim = Fout, bias = True).to(device)
    eval_model.load_state_dict(torch.load('./1BestMPSn'+str(X_train.size()[0])+'h'+str(nm)+'k'+str(nk), weights_only = True))
    print(criterion(y_test, eval_model(X_test).detach()))
# Out:
# tensor(1.5192)

# %%
MPSy = eval_model(X_train)
LambdaB = ECM(model = eval_model, num_neurons = nm, num_knots = nk)
print('Lambda: ', LambdaB)
# Out:
# Lambda:  0.5584757328033447

# %% [markdown]
# ##

# %%
plt.figure(figsize=(16,5))
plt.plot(np.arange(len(Lossdict['MBS400'][:-4])), Lossdict['MBS400'][:-4], label = '- MBS - batchsize 400')
plt.plot(np.arange(len(Lossdict['MPS400'][:-27])), Lossdict['MPS400'][:-27], label = '- MPS - batchsize 400')
plt.plot(np.arange(len(Lossdict['MBS2000'][:-27])), Lossdict['MBS2000'][:-27], label = '- MBS - batchsize 2000')
plt.plot(np.arange(len(Lossdict['MPS2000'][:-6])), Lossdict['MPS2000'][:-6], label = '- MPS - batchsize 2000')
plt.plot(np.arange(len(Lossdict['MBS4000'][:-35])), Lossdict['MBS4000'][:-35], label = '- MBS - batchsize 4000')
plt.plot(np.arange(len(Lossdict['MPS4000'][:-6])), Lossdict['MPS4000'][:-6], label = '- MPS - batchsize 4000')
plt.yscale("log")
plt.title('Mean Squared Training Error')
plt.xlabel('Epoch')
plt.ylabel('$\log-$Loss')
plt.legend()
plt.savefig('training_loss.png')
plt.grid()

# %% [markdown]
# ### Parameter sum

# %%
with torch.no_grad():
    X_test = torch.load('../Dataset/train400.pt', weights_only = True)['X_test']
    y_test = torch.load('../Dataset/train400.pt', weights_only = True)['y_test']

    eval_model = MPSv3(input_dim = Fin, degree = dg, num_knots = nk, num_neurons = nm, output_dim = Fout, bias = True).to(device)
    eval_model.load_state_dict(torch.load('./BestMBSn400'+'h'+str(nm)+'k'+str(nk), weights_only = True))
    print(criterion(y_test, eval_model(X_test).detach()))

    eval_model = MPSv3(input_dim = Fin, degree = dg, num_knots = nk, num_neurons = nm, output_dim = Fout, bias = True).to(device)
    eval_model.load_state_dict(torch.load('./BestMPSn400'+'h'+str(nm)+'k'+str(nk), weights_only = True))
    print(criterion(y_test, eval_model(X_test).detach()))

    X_test = torch.load('../Dataset/train2000.pt', weights_only = True)['X_test']
    y_test = torch.load('../Dataset/train2000.pt', weights_only = True)['y_test']

    eval_model = MPSv3(input_dim = Fin, degree = dg, num_knots = nk, num_neurons = nm, output_dim = Fout, bias = True).to(device)
    eval_model.load_state_dict(torch.load('./BestMBSn2000'+'h'+str(nm)+'k'+str(nk), weights_only = True))
    print(criterion(y_test, eval_model(X_test).detach()))
    
    eval_model = MPSv3(input_dim = Fin, degree = dg, num_knots = nk, num_neurons = nm, output_dim = Fout, bias = True).to(device)
    eval_model.load_state_dict(torch.load('./BestMPSn2000'+'h'+str(nm)+'k'+str(nk), weights_only = True))
    print(criterion(y_test, eval_model(X_test).detach()))

    X_test = torch.load('../Dataset/train4000.pt', weights_only = True)['X_test']
    y_test = torch.load('../Dataset/train4000.pt', weights_only = True)['y_test']
    eval_model = MPSv3(input_dim = Fin, degree = dg, num_knots = nk, num_neurons = nm, output_dim = Fout, bias = True).to(device)
    eval_model.load_state_dict(torch.load('./BestMBSn4000'+'h'+str(nm)+'k'+str(nk), weights_only = True))
    print(criterion(y_test, eval_model(X_test).detach()))

    eval_model = MPSv3(input_dim = Fin, degree = dg, num_knots = nk, num_neurons = nm, output_dim = Fout, bias = True).to(device)
    eval_model.load_state_dict(torch.load('./BestMPSn4000'+'h'+str(nm)+'k'+str(nk), weights_only = True))
    print(criterion(y_test, eval_model(X_test).detach()))
# Out:
# tensor(0.0359)
# tensor(0.0546)
# tensor(0.0302)
# tensor(0.0265)
# tensor(0.0303)
# tensor(0.0266)

# %%
cat_dict = {}
sizel = ['400', '2000', '4000']

for s in sizel:
    with torch.no_grad():
        eval_model = MPSv3(input_dim = Fin, degree = dg, num_knots = nk, num_neurons = nm, output_dim = Fout, bias = True).to(device)
        eval_model.load_state_dict(torch.load('./BestMBSn'+s+'h'+str(nm)+'k'+str(nk), weights_only = True))
        
    cat_par = None
    for name, param in eval_model.named_parameters():
        if param.requires_grad:
            if cat_par is None:
                cat_par = param.data.reshape(-1,1)
            else:
                cat_par = torch.cat([cat_par, param.data.reshape(-1,1)], dim = 0)

    par = cat_par.detach().numpy().reshape(-1)
    par = par * np.std(par)
    
    cat_dict['b'+s] = list(par)
    
sizel = ['400', '2000', '4000']

for s in sizel:
    with torch.no_grad():
        eval_model = MPSv3(input_dim = Fin, degree = dg, num_knots = nk, num_neurons = nm, output_dim = Fout, bias = True).to(device)
        eval_model.load_state_dict(torch.load('./BestMPSn'+s+'h'+str(nm)+'k'+str(nk), weights_only = True))
        
    cat_par = None
    for name, param in eval_model.named_parameters():
        if param.requires_grad:
            if cat_par is None:
                cat_par = param.data.reshape(-1,1)
            else:
                cat_par = torch.cat([cat_par, param.data.reshape(-1,1)], dim = 0)

    par = cat_par.detach().numpy().reshape(-1)
    par *= np.std(par)
    cat_dict['p'+s] = list(par)

# %%
cat = ['MBS(400)'] * len(cat_par) + ['MPS(400)'] * len(cat_par) + ['MBS(2000'] * len(cat_par) + ['MPS(2000)'] * len(cat_par) + ['MBS(4000)'] * len(cat_par)  + ['MPS(4000)'] * len(cat_par)
para = cat_dict['b400'] +  cat_dict['p400']  + cat_dict['b2000'] + cat_dict['p2000'] + cat_dict['b4000'] + cat_dict['p4000']
df = pd.DataFrame({'Class': cat, 'para': para})

# %%
# Change some of seaborn's style settings with `sns.set()`
plt.figure(figsize = (16, 5))
sns.set(
        style="ticks",                   # The 'ticks' style
        rc={"figure.figsize": (6, 9),      # width = 6, height = 9
            "figure.facecolor": "white",  # Figure colour
            "axes.facecolor": "white"})  # Axes colour# Box plot
b = sns.boxplot(data = df,           
                    x = "Class",       # x axis column from data
                    y = "para",       # y axis column from data
                    width = 0.4,        # The width of the boxes
                    color = "skyblue",  # Box colour
                    linewidth = 2,      # Thickness of the box lines
                    showfliers = False)  # Sop showing the fliers# Strip plot
b = sns.stripplot(data = df,          
                      x = "Class",      # x axis column from data
                      y = "para",      # y axis column from data
                      color = "crimson", # Colours the dots
                      linewidth = 1,     # Dot outline width
                      alpha = 0.4)       # Makes them transparent# Set the y axis and font size
b.set_ylabel("Coefficient", fontsize = 14)# Set the x axis label and font size
b.set_xlabel("Model(training size)", fontsize = 14)# Set the plot title with the pval variable and font size
b.set_title("Model Compression", fontsize = 16)# Remove axis spines
sns.despine(offset = 5, trim = True)# Show the figure
b.get_figure();

plt.savefig('boxcoef.png')

# %% [markdown]
# ## Nouse Function

# %%
'''
def ECM(model, num_neurons, num_knots, initial_xi = 1, initial_sigma = 1, initial_lambda = 1e-4):
    lambdab = initial_lambda
    sigma = initial_sigma
    xi = initial_xi
    
    B = model.inter['ebasic']
    By = model.inter['basic']
    WB = model.sp1.control_p
    DB = diag_mat_weights(WB.size()[0]).to(device)
    size = B.size()[1]
    S = DB.T @ DB
    Cov_a = (xi**2)* torch.linalg.pinv(S)
    Cov_e = torch.eye(size*num_neurons)* sigma
    
    block_y = torch.reshape(By, (-1,1))
    flatB = B.view(num_neurons, num_knots, size)
        
    sqr_xi= 0
    sqr_sig = 0
    
    for i in range(num_neurons):
        Ncov = (Cov_a -(Cov_a @ flatB[i]) @ (torch.linalg.pinv(flatB[i].T @ Cov_a @ flatB[i] + Cov_e[size*i:size*(i+1),size*i:size*(i+1)]) @ flatB[i].T @ Cov_a))
        Nmu = (Cov_a @ flatB[i]) @ (torch.linalg.pinv(flatB[i].T @ Cov_a @ flatB[i] + Cov_e[size*i:size*(i+1),size*i:size*(i+1)])) @ By[:,i].reshape(-1,1)
        
        first_xi = S @ Ncov
        second_xi = (Nmu.T @ S @ Nmu)
        sqr_xi += torch.trace(first_xi) + second_xi
            
        first_sig = torch.norm(By[:,i])
        second_sig = 2 * (By[:,i] @ flatB[i].T) @ Nmu 
        third_sig = torch.trace((flatB[i] @ flatB[i].T) @ Ncov)
        four_sig = (Nmu.T @ flatB[i] @ flatB[i].T @ Nmu)
        
        sqr_sig += (first_sig + second_sig + third_sig + four_sig)
    
    sqr_xi /= num_neurons
    sqr_sig /= (num_neurons*size)
    
    Lambda = sqr_sig/sqr_xi
    
    return Lambda.item()
